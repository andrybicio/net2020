# %%
import pandas as pd
import numpy as np

import networkx as nx
import itertools
from itertools import combinations

import statsmodels
import statsmodels.api as sm
import scipy.stats as stats

import matplotlib.pyplot as plt

# %%
###Import the clean tokens csv file
clean_words = pd.read_csv('all_tokens.csv')
df = pd.DataFrame(data = clean_words)
df.head()
# Out:
#    Unnamed: 0                                           text_nlp
# 0           0         dire gente guerra portata casa rimpatriati
# 1           1                                 marcello perfavore
# 2           2  patria patrioti difesa proprie radici soccombe...
# 3           3                           musulmani comandare casa
# 4           4                  odio dipende odio comandato libro

# %%
##rename the columns
df.columns = ["id","words"]
df.head()
# Out:
#    id                                              words
# 0   0         dire gente guerra portata casa rimpatriati
# 1   1                                 marcello perfavore
# 2   2  patria patrioti difesa proprie radici soccombe...
# 3   3                           musulmani comandare casa
# 4   4                  odio dipende odio comandato libro

# %%
##check for null values
df.isnull().values.any()
# Out:
# False

# %%
df.shape
# Out:
# (75775, 2)

# %%
##create a copy of the dataframe
df_words = df.copy()
df_words.shape
# Out:
# (75775, 2)

# %%
###tokenization using NLTK
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer

tokenizer = RegexpTokenizer(r'\w+')

# %%
##tokenize the comments
df_words['words'] = df['words'].apply(lambda s: tokenizer.tokenize(s))
df_words.head(20)
# Out:
#     id                                              words
# 0    0  [dire, gente, guerra, portata, casa, rimpatriati]
# 1    1                              [marcello, perfavore]
# 2    2  [patria, patrioti, difesa, proprie, radici, so...
# 3    3                       [musulmani, comandare, casa]
# 4    4            [odio, dipende, odio, comandato, libro]
# 5    5     [direi, dovremmo, diventare, razzisti, peggio]
# 6    6                  [meditate, sinistronzi, meditate]
# 7    7  [tolleranza, rispetta, cultura, legge, barcone...
# 8    8                                      [sottoscrivo]
# 9    9  [papa, francesco, giudichi, fatto, sicuro, deb...
# 10  10  [occhio, inghilterra, governano, lorsignori, l...
# 11  11  [corrado, armeri, creare, centro, raccolta, ri...
# 12  12  [senatore, iniziare, dire, verita, islam, paci...
# 13  13  [buonisti, comunisti, trasferta, trovarli, pos...
# 14  14  [gemmato, colgo, occasione, rammentare, propos...
# 15  15                                [escremento, umano]
# 16  16  [infilino, culetti, antifa, suppostina, figli,...
# 17  17      [pezzo, merda, via, italia, schifo, italiani]
# 18  18  [lurido, escremento, putrefatto, anti, italian...
# 19  19  [porta, ettari, ettari, terreni, alloggia, villa]

# %%
## create a dictionary of unique words

unique_words = {} ##58384
words_per_comment = {}

for index, row in df_words.iterrows():  ##iterating over the df
    if(len(row['words'])>0):  ##this gives the length of each row
        words_per_comment[row["id"]]= [clean_txt for clean_txt in row['words']] ###iterating the column text_clean. There are 78174 rows
        for clean_txt in row['words']:
            unique_words.setdefault(clean_txt, 0) ## setdefault() method returns the value of a key (if the key is in dictionary)
            unique_words[clean_txt] += 1

# %%
print(len(unique_words))
# Out:
# 57536

# %%
print(unique_words)
# Out:
# {'dire': 1568, 'gente': 1320, 'guerra': 497, 'portata': 45, 'casa': 1434, 'rimpatriati': 16, 'marcello': 146, 'perfavore': 12, 'patria': 205, 'patrioti': 11, 'difesa': 245, 'proprie': 92, 'radici': 58, 'soccombe': 1, 'roma': 595, 'islamico': 45, 'accoltella': 2, 'uomo': 467, 'crocifisso': 34, 'collo': 24, 'accaduto': 39, 'stazione': 24, 'termini': 76, 'aggressore': 2, 'fermato': 30, 'poliziotto': 14, 'notato': 35, 'vittima': 58, 'tentato': 21, 'sgozzarlo': 1, 'aumentare': 93, 'controlli': 52, 'attenzione': 157, 'prevenire': 12, 'violenza': 195, 'cittadini': 570, 'innocenti': 60, 'parte': 1476, 'islamici': 102, 'imperativo': 4, 'corrado': 23, 'armeri': 2, 'fdi': 75, 'musulmani': 108, 'comandare': 28, 'odio': 407, 'dipende': 46, 'comandato': 3, 'libro': 177, 'direi': 189, 'dovremmo': 94, 'diventare': 110, 'razzisti': 162, 'peggio': 455, 'meditate': 27, 'sinistronzi': 21, 'tolleranza': 59, 'rispetta': 46, 'cultura': 254, 'legge': 701, 'barcone': 32, 'via': 614, 'sottoscrivo': 17, 'papa': 306, 'francesco': 250, 'giudichi': 9, 'fatto': 2898, 'sicuro': 308, 'debbano': 26, 'baciare': 15, 'piedi': 143, 'possibili': 45, 'aguzzini': 6, 'occhio': 130, 'inghilterra': 16, 'governano': 22, 'lorsignori': 1, 'lotta': 146, 'conquista': 20, 'sfogliare': 1, 'corano': 9, 'silenziosa': 4, 'diventera': 15, 'sempre': 3929, 'rumorosa': 2, 'cominciano': 24, 'numeri': 116, 'grazie': 2811, 'politiche': 308, 'stolte': 1, 'miopi': 7, 'creare': 123, 'centro': 283, 'raccolta': 41, 'rispedirli': 2, 'indietro': 148, 'senatore': 58, 'iniziare': 43, 'verita': 377, 'islam': 101, 'pacifico': 9, 'vertici': 34, 'chiesa': 233, 'cattolica': 24, 'pensano': 170, 'diversamente': 72, 'paura': 346, 'parlare': 901, 'terrorismo': 42, 'matrice': 12, 'islamica': 34, 'buonisti': 123, 'comunisti': 323, 'trasferta': 7, 'trovarli': 4, 'possibilmente': 15, 'rimanerci': 5, 'gemmato': 18, 'colgo': 4, 'occasione': 130, 'rammentare': 1, 'proposta': 172, 'attuale': 158, 'pertinente': 3, 'compresa': 31, 'situazione': 231, 'italia': 3704, 'migliorata': 9, 'fronte': 141, 'cordiale': 8, 'saluto': 169, 'escremento': 3, 'umano': 100, 'infilino': 1, 'culetti': 1, 'antifa': 4, 'suppostina': 1, 'figli': 480, 'brigatista': 4, 'assassino': 30, 'pezzo': 105, 'merda': 471, 'schifo': 575, 'italiani': 2354, 'lurido': 9, 'putrefatto': 1, 'anti': 97, 'italiano': 717, 'servo': 24, 'pd': 2559, 'sinistroidi': 53, 'feccia': 97, 'umanita': 133, 'vergognatevi': 135, 'porta': 221, 'ettari': 7, 'terreni': 7, 'alloggia': 2, 'villa': 27, 'chimica': 65, 'castrare': 10, 'colpo': 73, 'forbice': 5, 'castrazione': 94, 'traumatica': 1, 'forza': 1817, 'cura': 66, 'ricostituente': 1, 'calci': 96, 'condivido': 289, 'accetta': 23, 'fisica': 29, 'galera': 231, 'chirurgica': 10, 'bufala': 81, 'unico': 437, 'paese': 1451, 'mondo': 734, 'poliziotti': 54, 'carabinieri': 80, 'forze': 287, 'ordine': 299, 'generale': 109, 'vengono': 285, 'picchiati': 4, 'insultati': 5, 'minacciati': 4, 'ridicoli': 122, 'capovolto': 4, 'regole': 137, 'vivere': 228, 'civile': 200, 'razza': 96, 'centri': 159, 'asociali': 2, 'clandestini': 259, 'delinquenti': 280, 'comuni': 130, 'permettono': 38, 'magistratura': 155, 'vergognosa': 61, 'fuori': 799, 'realta': 349, 'impunita': 12, 'garantita': 12, 'vergogno': 40, 'ridotto': 84, 'erro': 12, 'anni': 2205, 'parlava': 61, 'oltraggio': 5, 'pubblico': 245, 'ufficiale': 51, 'quando': 2481, 'osava': 2, 'ribellarsi': 3, 'confronti': 131, 'carabiniere': 18, 'rappresentanti': 56, 'invertite': 5, 'parti': 100, 'guai': 63, 'tutori': 4, 'dovessero': 22, 'sfiorare': 2, 'gentaglia': 67, 'specie': 98, 'bianchi': 67, 'neri': 80, 'farsi': 244, 'massacrare': 8, 'rifiuti': 56, 'societa': 176, 'amati': 14, 'coccolati': 1, 'entrare': 173, 'quantita': 27, 'incontrollata': 14, 'cavoli': 25, 'amari': 11, 'lezione': 47, 'teaser': 3, 'persone': 1399, 'spaccategli': 1, 'sedere': 37, 'gentile': 85, 'spaccare': 9, 'bastardo': 30, 'tornare': 177, 'cammelli': 3, 'serviva': 15, 'seconda': 127, 'volante': 4, 'bastava': 33, 'agente': 12, ...

# %%
##create a matrix of words
clean_df = pd.DataFrame(0, index=unique_words, columns=unique_words)

for key in words_per_comment:
    for pair in itertools.product(words_per_comment[key],words_per_comment[key]):
        if pair[0]!=pair[1] and not(clean_df.at[pair[0],pair[1]]):
            clean_df.at[pair[0],pair[1]] += 1
            clean_df.at[pair[1],pair[0]] += 1

# %%
display(clean_df) ##this is the full matrix of words
# Out:
#                     dire  gente  guerra  portata  casa  rimpatriati  marcello  \
# dire                   0      1       1        1     1            1         1
# gente                  1      0       1        1     1            1         1
# guerra                 1      1       0        1     1            1         0
# portata                1      1       1        0     1            1         0
# casa                   1      1       1        1     0            1         1
# ...                  ...    ...     ...      ...   ...          ...       ...
# aspettandoprometeo     0      0       0        0     0            0         0
# ivreich                0      0       0        0     0            0         0
# satanassi              0      0       0        0     0            0         0
# pezzettino             0      0       0        0     0            0         0
# consigliatissima       0      0       0        0     0            0         0
#
#                     perfavore  patria  patrioti  ...  patteggiamenti  \
# dire                        0       1         1  ...               0
# gente                       0       1         1  ...               0
# guerra                      0       1         0  ...               0
# portata                     0       0         0  ...               0
# casa                        0       1         1  ...               0
# ...                       ...     ...       ...  ...             ...
# aspettandoprometeo          0       0         0  ...               0
# ivreich                     0       0         0  ...               0
# satanassi                   0       0         0  ...               0
# pezzettino                  0       0         0  ...               0
# consigliatissima            0       0         0  ...               0
#
#                     quellivche  ndrine  earth  rip  aspettandoprometeo  \
# dire                         1       1      0    0                   0
# gente                        0       0      0    0                   0
# guerra                       0       0      0    0                   0
# portata                      0       0      0    0                   0
# casa                         0       0      0    0                   0
# ...                        ...     ...    ...  ...                 ...
# aspettandoprometeo           0       0      1    1                   0
# ivreich                      0       0      1    1                   1
# satanassi                    0       0      0    0                   0
# pezzettino                   0       0      0    0                   0
# consigliatissima             0       0      0    0                   0
#
#                     ivreich  satanassi  pezzettino  consigliatissima
# dire                      0          0           0                 0
# gente                     0          0           0                 0
# guerra                    0          0           0                 0
# portata                   0          0           0                 0
# casa                      0          0           0                 0
# ...                     ...        ...         ...               ...
# aspettandoprometeo        1          0           0                 0
# ivreich                   0          0           0                 0
# satanassi                 0          0           0                 0
# pezzettino                0          0           0                 0
# consigliatissima          0          0           0                 0
#
# [57536 rows x 57536 columns]

# %%
##use this as a basis to get edges and their weights

words_projection = {} ##create dictionary 
##itertools.product() which computes the cartesian product of input iterables.

for key in words_per_comment:
    for pair in itertools.product(words_per_comment[key],words_per_comment[key]):
        if pair[0]!=pair[1] and not(pair[::-1] in words_projection):
            words_projection.setdefault(pair,0)
            words_projection[pair] += 1

words_projection
# Out:
# {('dire', 'gente'): 60,
#  ('dire', 'guerra'): 23,
#  ('dire', 'portata'): 3,
#  ('dire', 'casa'): 79,
#  ('dire', 'rimpatriati'): 3,
#  ('gente', 'guerra'): 8,
#  ('gente', 'portata'): 4,
#  ('gente', 'casa'): 63,
#  ('gente', 'rimpatriati'): 1,
#  ('guerra', 'portata'): 3,
#  ('guerra', 'casa'): 31,
#  ('guerra', 'rimpatriati'): 1,
#  ('portata', 'casa'): 6,
#  ('portata', 'rimpatriati'): 1,
#  ('casa', 'rimpatriati'): 3,
#  ('marcello', 'perfavore'): 1,
#  ('patria', 'patrioti'): 2,
#  ('patria', 'difesa'): 6,
#  ('patria', 'proprie'): 5,
#  ('patria', 'radici'): 1,
#  ('patria', 'soccombe'): 1,
#  ('patria', 'roma'): 5,
#  ('patria', 'islamico'): 3,
#  ('patria', 'accoltella'): 1,
#  ('patria', 'uomo'): 17,
#  ('patria', 'crocifisso'): 1,
#  ('patria', 'collo'): 1,
#  ('patria', 'accaduto'): 1,
#  ('patria', 'stazione'): 1,
#  ('patria', 'termini'): 5,
#  ('patria', 'aggressore'): 1,
#  ('patria', 'fermato'): 1,
#  ('patria', 'poliziotto'): 1,
#  ('patria', 'notato'): 1,
#  ('patria', 'vittima'): 2,
#  ('patria', 'tentato'): 1,
#  ('patria', 'sgozzarlo'): 1,
#  ('patria', 'aumentare'): 1,
#  ('patria', 'controlli'): 1,
#  ('patria', 'attenzione'): 1,
#  ('patria', 'prevenire'): 1,
#  ('patria', 'violenza'): 1,
#  ('patria', 'cittadini'): 54,
#  ('patria', 'innocenti'): 1,
#  ('patria', 'parte'): 22,
#  ('patria', 'islamici'): 4,
#  ('patria', 'imperativo'): 1,
#  ('patria', 'corrado'): 1,
#  ('patria', 'armeri'): 1,
#  ('patria', 'fdi'): 2,
#  ('patrioti', 'difesa'): 1,
#  ('patrioti', 'proprie'): 1,
#  ('patrioti', 'radici'): 1,
#  ('patrioti', 'soccombe'): 1,
#  ('patrioti', 'roma'): 3,
#  ('patrioti', 'islamico'): 1,
#  ('patrioti', 'accoltella'): 1,
#  ('patrioti', 'uomo'): 1,
#  ('patrioti', 'crocifisso'): 1,
#  ('patrioti', 'collo'): 1,
#  ('patrioti', 'accaduto'): 1,
#  ('patrioti', 'stazione'): 1,
#  ('patrioti', 'termini'): 1,
#  ('patrioti', 'aggressore'): 1,
#  ('patrioti', 'fermato'): 1,
#  ('patrioti', 'poliziotto'): 1,
#  ('patrioti', 'notato'): 1,
#  ('patrioti', 'vittima'): 1,
#  ('patrioti', 'tentato'): 1,
#  ('patrioti', 'sgozzarlo'): 1,
#  ('patrioti', 'aumentare'): 1,
#  ('patrioti', 'controlli'): 1,
#  ('patrioti', 'attenzione'): 1,
#  ('patrioti', 'prevenire'): 1,
#  ('patrioti', 'violenza'): 1,
#  ('patrioti', 'cittadini'): 9,
#  ('patrioti', 'innocenti'): 1,
#  ('patrioti', 'parte'): 1,
#  ('patrioti', 'islamici'): 1,
#  ('patrioti', 'imperativo'): 1,
#  ('patrioti', 'corrado'): 1,
#  ('patrioti', 'armeri'): 1,
#  ('patrioti', 'fdi'): 1,
#  ('difesa', 'proprie'): 2,
#  ('difesa', 'radici'): 1,
#  ('difesa', 'soccombe'): 1,
#  ('difesa', 'roma'): 8,
#  ('difesa', 'islamico'): 1,
#  ('difesa', 'accoltella'): 1,
#  ('difesa', 'uomo'): 6,
#  ('difesa', 'crocifisso'): 2,
#  ('difesa', 'collo'): 2,
#  ('difesa', 'accaduto'): 1,
#  ('difesa', 'stazione'): 1,
#  ('difesa', 'termini'): 2,
#  ('difesa', 'aggressore'): 1,
#  ('difesa', 'fermato'): 1,
#  ('difesa', 'poliziotto'): 1,
#  ('difesa', 'notato'): 1,
#  ('difesa', 'vittima'): 6,
#  ('difesa', 'tentato'): 1,
#  ('difesa', 'sgozzarlo'): 1,
#  ('difesa', 'aumentare'): 1,
#  ('difesa', 'controlli'): 1,
#  ('difesa', 'attenzione'): 5,
#  ('difesa', 'prevenire'): 1,
#  ('difesa', 'violenza'): 7,
#  ('difesa', 'cittadini'): 18,
#  ('difesa', 'innocenti'): 6,
#  ('difesa', 'parte'): 17,
#  ('difesa', 'islamici'): 2,
#  ('difesa', 'imperativo'): 1,
#  ('difesa', 'corrado'): 1,
#  ('difesa', 'armeri'): 1,
#  ('difesa', 'fdi'): 1,
#  ('proprie', 'radici'): 4,
#  ('proprie', 'soccombe'): 1,
#  ('proprie', 'roma'): 4,
#  ('proprie', 'islamico'): 3,
#  ('proprie', 'accoltella'): 1,
#  ('proprie', 'uomo'): 2,
#  ('proprie', 'crocifisso'): 1,
#  ('proprie', 'collo'): 1,
#  ('proprie', 'accaduto'): 1,
#  ('proprie', 'stazione'): 1,
#  ('proprie', 'termini'): 1,
#  ('proprie', 'aggressore'): 1,
#  ('proprie', 'fermato'): 1,
#  ('proprie', 'poliziotto'): 1,
#  ('proprie', 'notato'): 1,
#  ('proprie', 'vittima'): 1,
#  ('proprie', 'tentato'): 1,
#  ('proprie', 'sgozzarlo'): 1,
#  ('proprie', 'aumentare'): 1,
#  ('proprie', 'controlli'): 1,
#  ('proprie', 'attenzione'): 2,
#  ('proprie', 'prevenire'): 3,
#  ('proprie', 'violenza'): 3,
#  ('proprie', 'cittadini'): 5,
#  ('proprie', 'innocenti'): 1,
#  ('proprie', 'parte'): 9,
#  ('proprie', 'islamici'): 3,
#  ('proprie', 'imperativo'): 1,
#  ('proprie', 'corrado'): 1,
#  ('proprie', 'armeri'): 1,
#  ('proprie', 'fdi'): 1,
#  ('radici', 'soccombe'): 1,
#  ('radici', 'roma'): 2,
#  ('radici', 'islamico'): 1,
#  ('radici', 'accoltella'): 1,
#  ('radici', 'uomo'): 2,
#  ('radici', 'crocifisso'): 1,
#  ('radici', 'collo'): 1,
#  ('radici', 'accaduto'): 1,
#  ('radici', 'stazione'): 1,
#  ('radici', 'termini'): 2,
#  ('radici', 'aggressore'): 1,
#  ('radici', 'fermato'): 1,
#  ('radici', 'poliziotto'): 1,
#  ('radici', 'notato'): 1,
#  ('radici', 'vittima'): 1,
#  ('radici', 'tentato'): 1,
#  ('radici', 'sgozzarlo'): 1,
#  ('radici', 'aumentare'): 1,
#  ('radici', 'controlli'): 1,
#  ('radici', 'attenzione'): 1,
#  ('radici', 'prevenire'): 1,
#  ('radici', 'violenza'): 2,
#  ('radici', 'cittadini'): 2,
#  ('radici', 'innocenti'): 1,
#  ('radici', 'parte'): 6,
#  ('radici', 'islamici'): 2,
#  ('radici', 'imperativo'): 1,
#  ('radici', 'corrado'): 1,
#  ('radici', 'armeri'): 1,
#  ('radici', 'fdi'): 1,
#  ('soccombe', 'roma'): 2,
#  ('soccombe', 'islamico'): 1,
#  ('soccombe', 'accoltella'): 1,
#  ('soccombe', 'uomo'): 1,
#  ('soccombe', 'crocifisso'): 1,
#  ('soccombe', 'collo'): 1,
#  ('soccombe', 'accaduto'): 1,
#  ('soccombe', 'stazione'): 1,
#  ('soccombe', 'termini'): 1,
#  ('soccombe', 'aggressore'): 1,
#  ('soccombe', 'fermato'): 1,
#  ('soccombe', 'poliziotto'): 1,
#  ('soccombe', 'notato'): 1,
#  ('soccombe', 'vittima'): 1,
#  ('soccombe', 'tentato'): 1,
#  ('soccombe', 'sgozzarlo'): 1,
#  ('soccombe', 'aumentare'): 1,
#  ('soccombe', 'controlli'): 1,
#  ('soccombe', 'attenzione'): 1,
#  ('soccombe', 'prevenire'): 1,
#  ('soccombe', 'violenza'): 1,
#  ('soccombe', 'cittadini'): 1,
#  ('soccombe', 'innocenti'): 1,
#  ('soccombe', 'parte'): 1,
#  ('soccombe', 'islamici'): 1,
#  ('soccombe', 'imperativo'): 1,
#  ('soccombe', 'corrado'): 1,
#  ('soccombe', 'armeri'): 1,
#  ('soccombe', 'fdi'): 1,
#  ('roma', 'islamico'): 4,
#  ('roma', 'accoltella'): 2,
#  ('roma', 'uomo'): 22,
#  ('roma', 'crocifisso'): 2,
#  ('roma', 'collo'): 2,
#  ('roma', 'accaduto'): 4,
#  ('roma', 'stazione'): 2,
#  ('roma', 'termini'): 2,
#  ('roma', 'aggressore'): 2,
#  ('roma', 'fermato'): 2,
#  ('roma', 'poliziotto'): 2,
#  ('roma', 'notato'): 2,
#  ('roma', 'vittima'): 20,
#  ('roma', 'tentato'): 2,
#  ('roma', 'sgozzarlo'): 2,
#  ('roma', 'aumentare'): 2,
#  ('roma', 'controlli'): 2,
#  ('roma', 'attenzione'): 13,
#  ('roma', 'prevenire'): 2,
#  ('roma', 'violenza'): 6,
#  ('roma', 'cittadini'): 39,
#  ('roma', 'innocenti'): 4,
#  ('roma', 'parte'): 42,
#  ('roma', 'islamici'): 3,
#  ('roma', 'imperativo'): 2,
#  ('roma', 'corrado'): 3,
#  ('roma', 'armeri'): 2,
#  ('roma', 'fdi'): 4,
#  ('islamico', 'accoltella'): 1,
#  ('islamico', 'uomo'): 2,
#  ('islamico', 'crocifisso'): 2,
#  ('islamico', 'collo'): 1,
#  ('islamico', 'accaduto'): 1,
#  ('islamico', 'stazione'): 1,
#  ('islamico', 'termini'): 2,
#  ('islamico', 'aggressore'): 1,
#  ('islamico', 'fermato'): 1,
#  ('islamico', 'poliziotto'): 1,
#  ('islamico', 'notato'): 1,
#  ('islamico', 'vittima'): 2,
#  ('islamico', 'tentato'): 1,
#  ('islamico', 'sgozzarlo'): 1,
#  ('islamico', 'aumentare'): 1,
#  ('islamico', 'controlli'): 1,
#  ('islamico', 'attenzione'): 1,
#  ('islamico', 'prevenire'): 1,
#  ('islamico', 'violenza'): 5,
#  ('islamico', 'cittadini'): 1,
#  ('islamico', 'innocenti'): 1,
#  ('islamico', 'parte'): 4,
#  ('islamico', 'islamici'): 6,
#  ('islamico', 'imperativo'): 1,
#  ('islamico', 'corrado'): 1,
#  ('islamico', 'armeri'): 1,
#  ('islamico', 'fdi'): 1,
#  ('accoltella', 'uomo'): 1,
#  ('accoltella', 'crocifisso'): 3,
#  ('accoltella', 'collo'): 1,
#  ('accoltella', 'accaduto'): 1,
#  ('accoltella', 'stazione'): 1,
#  ('accoltella', 'termini'): 1,
#  ('accoltella', 'aggressore'): 1,
#  ('accoltella', 'fermato'): 1,
#  ('accoltella', 'poliziotto'): 1,
#  ('accoltella', 'notato'): 1,
#  ('accoltella', 'vittima'): 1,
#  ('accoltella', 'tentato'): 1,
#  ('accoltella', 'sgozzarlo'): 1,
#  ('accoltella', 'aumentare'): 1,
#  ('accoltella', 'controlli'): 1,
#  ('accoltella', 'attenzione'): 1,
#  ('accoltella', 'prevenire'): 1,
#  ('accoltella', 'violenza'): 1,
#  ('accoltella', 'cittadini'): 1,
#  ('accoltella', 'innocenti'): 1,
#  ('accoltella', 'parte'): 1,
#  ('accoltella', 'islamici'): 1,
#  ('accoltella', 'imperativo'): 1,
#  ('accoltella', 'corrado'): 1,
#  ('accoltella', 'armeri'): 1,
#  ('accoltella', 'fdi'): 1,
#  ('uomo', 'crocifisso'): 2,
#  ('uomo', 'collo'): 1,
#  ('uomo', 'accaduto'): 1,
#  ('uomo', 'stazione'): 1,
#  ('uomo', 'termini'): 2,
#  ('uomo', 'aggressore'): 2,
#  ('uomo', 'fermato'): 1,
#  ('uomo', 'poliziotto'): 1,
#  ('uomo', 'notato'): 1,
#  ('uomo', 'vittima'): 6,
#  ('uomo', 'tentato'): 1,
#  ('uomo', 'sgozzarlo'): 1,
#  ('uomo', 'aumentare'): 1,
#  ('uomo', 'controlli'): 1,
#  ('uomo', 'attenzione'): 4,
#  ('uomo', 'prevenire'): 1,
#  ('uomo', 'violenza'): 4,
#  ('uomo', 'cittadini'): 26,
#  ('uomo', 'innocenti'): 3,
#  ('uomo', 'parte'): 46,
#  ('uomo', 'islamici'): 2,
#  ('uomo', 'imperativo'): 1,
#  ('uomo', 'corrado'): 1,
#  ('uomo', 'armeri'): 1,
#  ('uomo', 'fdi'): 1,
#  ('crocifisso', 'collo'): 7,
#  ('crocifisso', 'accaduto'): 1,
#  ('crocifisso', 'stazione'): 1,
#  ('crocifisso', 'termini'): 1,
#  ('crocifisso', 'aggressore'): 1,
#  ('crocifisso', 'fermato'): 1,
#  ('crocifisso', 'poliziotto'): 1,
#  ('crocifisso', 'notato'): 1,
#  ('crocifisso', 'vittima'): 1,
#  ('crocifisso', 'tentato'): 1,
#  ('crocifisso', 'sgozzarlo'): 1,
#  ('crocifisso', 'aumentare'): 1,
#  ('crocifisso', 'controlli'): 1,
#  ('crocifisso', 'attenzione'): 1,
#  ('crocifisso', 'prevenire'): 1,
#  ('crocifisso', 'violenza'): 4,
#  ('crocifisso', 'cittadini'): 1,
#  ('crocifisso', 'innocenti'): 2,
#  ('crocifisso', 'parte'): 2,
#  ('crocifisso', 'islamici'): 2,
#  ('crocifisso', 'imperativo'): 1,
#  ('crocifisso', 'corrado'): 1,
#  ('crocifisso', 'armeri'): 1,
#  ('crocifisso', 'fdi'): 1,
#  ('collo', 'accaduto'): 1,
#  ('collo', 'stazione'): 1,
#  ('collo', 'termini'): 1,
#  ('collo', 'aggressore'): 1,
#  ('collo', 'fermato'): 1,
#  ('collo', 'poliziotto'): 1,
#  ('collo', 'notato'): 1,
#  ('collo', 'vittima'): 1,
#  ('collo', 'tentato'): 1,
#  ('collo', 'sgozzarlo'): 1,
#  ('collo', 'aumentare'): 1,
#  ('collo', 'controlli'): 1,
#  ('collo', 'attenzione'): 1,
#  ('collo', 'prevenire'): 1,
#  ('collo', 'violenza'): 1,
#  ('collo', 'cittadini'): 1,
#  ('collo', 'innocenti'): 1,
#  ('collo', 'parte'): 3,
#  ('collo', 'islamici'): 1,
#  ('collo', 'imperativo'): 1,
#  ('collo', 'corrado'): 1,
#  ('collo', 'armeri'): 1,
#  ('collo', 'fdi'): 1,
#  ('accaduto', 'stazione'): 1,
#  ('accaduto', 'termini'): 1,
#  ('accaduto', 'aggressore'): 1,
#  ('accaduto', 'fermato'): 1,
#  ('accaduto', 'poliziotto'): 1,
#  ('accaduto', 'notato'): 1,
#  ('accaduto', 'vittima'): 1,
#  ('accaduto', 'tentato'): 1,
#  ('accaduto', 'sgozzarlo'): 1,
#  ('accaduto', 'aumentare'): 1,
#  ('accaduto', 'controlli'): 1,
#  ('accaduto', 'attenzione'): 1,
#  ('accaduto', 'prevenire'): 1,
#  ('accaduto', 'violenza'): 1,
#  ('accaduto', 'cittadini'): 5,
#  ('accaduto', 'innocenti'): 2,
#  ('accaduto', 'parte'): 5,
#  ('accaduto', 'islamici'): 1,
#  ('accaduto', 'imperativo'): 1,
#  ('accaduto', 'corrado'): 1,
#  ('accaduto', 'armeri'): 1,
#  ('accaduto', 'fdi'): 1,
#  ('stazione', 'termini'): 2,
#  ('stazione', 'aggressore'): 1,
#  ('stazione', 'fermato'): 1,
#  ('stazione', 'poliziotto'): 1,
#  ('stazione', 'notato'): 1,
#  ('stazione', 'vittima'): 1,
#  ('stazione', 'tentato'): 1,
#  ('stazione', 'sgozzarlo'): 1,
#  ('stazione', 'aumentare'): 1,
#  ('stazione', 'controlli'): 1,
#  ('stazione', 'attenzione'): 1,
#  ('stazione', 'prevenire'): 1,
#  ('stazione', 'violenza'): 2,
#  ('stazione', 'cittadini'): 1,
#  ('stazione', 'innocenti'): 1,
#  ('stazione', 'parte'): 1,
#  ('stazione', 'islamici'): 1,
#  ('stazione', 'imperativo'): 1,
#  ('stazione', 'corrado'): 1,
#  ('stazione', 'armeri'): 1,
#  ('stazione', 'fdi'): 1,
#  ('termini', 'aggressore'): 1,
#  ('termini', 'fermato'): 1,
#  ('termini', 'poliziotto'): 1,
#  ('termini', 'notato'): 1,
#  ('termini', 'vittima'): 1,
#  ('termini', 'tentato'): 1,
#  ('termini', 'sgozzarlo'): 1,
#  ('termini', 'aumentare'): 1,
#  ('termini', 'controlli'): 3,
#  ('termini', 'attenzione'): 1,
#  ('termini', 'prevenire'): 1,
#  ('termini', 'violenza'): 1,
#  ('termini', 'cittadini'): 3,
#  ('termini', 'innocenti'): 1,
#  ('termini', 'parte'): 3,
#  ('termini', 'islamici'): 2,
#  ('termini', 'imperativo'): 1,
#  ('termini', 'corrado'): 1,
#  ('termini', 'armeri'): 1,
#  ('termini', 'fdi'): 1,
#  ('aggressore', 'fermato'): 1,
#  ('aggressore', 'poliziotto'): 1,
#  ('aggressore', 'notato'): 1,
#  ('aggressore', 'vittima'): 1,
#  ('aggressore', 'tentato'): 1,
#  ('aggressore', 'sgozzarlo'): 1,
#  ('aggressore', 'aumentare'): 1,
#  ('aggressore', 'controlli'): 1,
#  ('aggressore', 'attenzione'): 1,
#  ('aggressore', 'prevenire'): 1,
#  ('aggressore', 'violenza'): 1,
#  ('aggressore', 'cittadini'): 1,
#  ('aggressore', 'innocenti'): 1,
#  ('aggressore', 'parte'): 1,
#  ('aggressore', 'islamici'): 1,
#  ('aggressore', 'imperativo'): 1,
#  ('aggressore', 'corrado'): 1,
#  ('aggressore', 'armeri'): 1,
#  ('aggressore', 'fdi'): 1,
#  ('fermato', 'poliziotto'): 1,
#  ('fermato', 'notato'): 1,
#  ('fermato', 'vittima'): 1,
#  ('fermato', 'tentato'): 1,
#  ('fermato', 'sgozzarlo'): 1,
#  ('fermato', 'aumentare'): 1,
#  ('fermato', 'controlli'): 1,
#  ('fermato', 'attenzione'): 2,
#  ('fermato', 'prevenire'): 1,
#  ('fermato', 'violenza'): 1,
#  ('fermato', 'cittadini'): 2,
#  ('fermato', 'innocenti'): 2,
#  ('fermato', 'parte'): 3,
#  ('fermato', 'islamici'): 1,
#  ('fermato', 'imperativo'): 1,
#  ('fermato', 'corrado'): 1,
#  ('fermato', 'armeri'): 1,
#  ('fermato', 'fdi'): 1,
#  ('poliziotto', 'notato'): 1,
#  ('poliziotto', 'vittima'): 1,
#  ('poliziotto', 'tentato'): 1,
#  ('poliziotto', 'sgozzarlo'): 1,
#  ('poliziotto', 'aumentare'): 1,
#  ('poliziotto', 'controlli'): 1,
#  ('poliziotto', 'attenzione'): 1,
#  ('poliziotto', 'prevenire'): 1,
#  ('poliziotto', 'violenza'): 1,
#  ('poliziotto', 'cittadini'): 1,
#  ('poliziotto', 'innocenti'): 1,
#  ('poliziotto', 'parte'): 1,
#  ('poliziotto', 'islamici'): 1,
#  ('poliziotto', 'imperativo'): 1,
#  ('poliziotto', 'corrado'): 1,
#  ('poliziotto', 'armeri'): 1,
#  ('poliziotto', 'fdi'): 1,
#  ('notato', 'vittima'): 1,
#  ('notato', 'tentato'): 1,
#  ('notato', 'sgozzarlo'): 1,
#  ('notato', 'aumentare'): 1,
#  ('notato', 'controlli'): 1,
#  ('notato', 'attenzione'): 2,
#  ('notato', 'prevenire'): 1,
#  ('notato', 'violenza'): 3,
#  ('notato', 'cittadini'): 1,
#  ('notato', 'innocenti'): 1,
#  ('notato', 'parte'): 7,
#  ('notato', 'islamici'): 1,
#  ('notato', 'imperativo'): 1,
#  ('notato', 'corrado'): 1,
#  ('notato', 'armeri'): 1,
#  ('notato', 'fdi'): 1,
#  ('vittima', 'tentato'): 4,
#  ('vittima', 'sgozzarlo'): 1,
#  ('vittima', 'aumentare'): 1,
#  ('vittima', 'controlli'): 1,
#  ('vittima', 'attenzione'): 3,
#  ('vittima', 'prevenire'): 1,
#  ('vittima', 'violenza'): 15,
#  ('vittima', 'cittadini'): 1,
#  ('vittima', 'innocenti'): 1,
#  ('vittima', 'parte'): 5,
#  ('vittima', 'islamici'): 1,
#  ('vittima', 'imperativo'): 1,
#  ('vittima', 'corrado'): 1,
#  ('vittima', 'armeri'): 1,
#  ('vittima', 'fdi'): 1,
#  ('tentato', 'sgozzarlo'): 1,
#  ('tentato', 'aumentare'): 1,
#  ('tentato', 'controlli'): 1,
#  ('tentato', 'attenzione'): 1,
#  ('tentato', 'prevenire'): 1,
#  ('tentato', 'violenza'): 5,
#  ('tentato', 'cittadini'): 1,
#  ('tentato', 'innocenti'): 1,
#  ('tentato', 'parte'): 6,
#  ('tentato', 'islamici'): 1,
#  ('tentato', 'imperativo'): 1,
#  ('tentato', 'corrado'): 1,
#  ('tentato', 'armeri'): 1,
#  ('tentato', 'fdi'): 1,
#  ('sgozzarlo', 'aumentare'): 1,
#  ('sgozzarlo', 'controlli'): 1,
#  ('sgozzarlo', 'attenzione'): 1,
#  ('sgozzarlo', 'prevenire'): 1,
#  ('sgozzarlo', 'violenza'): 1,
#  ('sgozzarlo', 'cittadini'): 1,
#  ('sgozzarlo', 'innocenti'): 1,
#  ('sgozzarlo', 'parte'): 1,
#  ('sgozzarlo', 'islamici'): 1,
#  ('sgozzarlo', 'imperativo'): 1,
#  ('sgozzarlo', 'corrado'): 1,
#  ('sgozzarlo', 'armeri'): 1,
#  ('sgozzarlo', 'fdi'): 1,
#  ('aumentare', 'controlli'): 1,
#  ('aumentare', 'attenzione'): 1,
#  ('aumentare', 'prevenire'): 1,
#  ('aumentare', 'violenza'): 1,
#  ('aumentare', 'cittadini'): 4,
#  ('aumentare', 'innocenti'): 3,
#  ('aumentare', 'parte'): 5,
#  ('aumentare', 'islamici'): 1,
#  ('aumentare', 'imperativo'): 1,
#  ('aumentare', 'corrado'): 2,
#  ('aumentare', 'armeri'): 1,
#  ('aumentare', 'fdi'): 1,
#  ('controlli', 'attenzione'): 3,
#  ('controlli', 'prevenire'): 1,
#  ('controlli', 'violenza'): 1,
#  ('controlli', 'cittadini'): 1,
#  ('controlli', 'innocenti'): 1,
#  ('controlli', 'parte'): 4,
#  ('controlli', 'islamici'): 2,
#  ('controlli', 'imperativo'): 1,
#  ('controlli', 'corrado'): 1,
#  ('controlli', 'armeri'): 1,
#  ('controlli', 'fdi'): 1,
#  ('attenzione', 'prevenire'): 1,
#  ('attenzione', 'violenza'): 2,
#  ('attenzione', 'cittadini'): 8,
#  ('attenzione', 'innocenti'): 3,
#  ('attenzione', 'parte'): 10,
#  ('attenzione', 'islamici'): 1,
#  ('attenzione', 'imperativo'): 1,
#  ('attenzione', 'corrado'): 1,
#  ('attenzione', 'armeri'): 1,
#  ('attenzione', 'fdi'): 1,
#  ('prevenire', 'violenza'): 3,
#  ('prevenire', 'cittadini'): 3,
#  ('prevenire', 'innocenti'): 1,
#  ('prevenire', 'parte'): 1,
#  ('prevenire', 'islamici'): 1,
#  ('prevenire', 'imperativo'): 1,
#  ('prevenire', 'corrado'): 1,
#  ('prevenire', 'armeri'): 1,
#  ('prevenire', 'fdi'): 1,
#  ('violenza', 'cittadini'): 7,
#  ('violenza', 'innocenti'): 2,
#  ('violenza', 'parte'): 13,
#  ('violenza', 'islamici'): 3,
#  ('violenza', 'imperativo'): 1,
#  ('violenza', 'corrado'): 1,
#  ('violenza', 'armeri'): 1,
#  ('violenza', 'fdi'): 1,
#  ('cittadini', 'innocenti'): 5,
#  ('cittadini', 'parte'): 67,
#  ('cittadini', 'islamici'): 1,
#  ('cittadini', 'imperativo'): 1,
#  ('cittadini', 'corrado'): 1,
#  ('cittadini', 'armeri'): 1,
#  ('cittadini', 'fdi'): 3,
#  ('innocenti', 'parte'): 6,
#  ('innocenti', 'islamici'): 2,
#  ('innocenti', 'imperativo'): 1,
#  ('innocenti', 'corrado'): 1,
#  ('innocenti', 'armeri'): 1,
#  ('innocenti', 'fdi'): 1,
#  ('parte', 'islamici'): 3,
#  ('parte', 'imperativo'): 1,
#  ('parte', 'corrado'): 1,
#  ('parte', 'armeri'): 1,
#  ('parte', 'fdi'): 5,
#  ('islamici', 'imperativo'): 1,
#  ('islamici', 'corrado'): 1,
#  ('islamici', 'armeri'): 1,
#  ('islamici', 'fdi'): 1,
#  ('imperativo', 'corrado'): 1,
#  ('imperativo', 'armeri'): 1,
#  ('imperativo', 'fdi'): 1,
#  ('corrado', 'armeri'): 2,
#  ('corrado', 'fdi'): 1,
#  ('armeri', 'fdi'): 1,
#  ('musulmani', 'comandare'): 1,
#  ('musulmani', 'casa'): 2,
#  ('comandare', 'casa'): 9,
#  ('odio', 'dipende'): 2,
#  ('odio', 'comandato'): 2,
#  ('odio', 'libro'): 3,
#  ('dipende', 'comandato'): 1,
#  ('dipende', 'libro'): 3,
#  ('comandato', 'libro'): 1,
#  ('direi', 'dovremmo'): 1,
#  ('direi', 'diventare'): 1,
#  ('direi', 'razzisti'): 2,
#  ('direi', 'peggio'): 1,
#  ('dovremmo', 'diventare'): 2,
#  ('dovremmo', 'razzisti'): 2,
#  ('dovremmo', 'peggio'): 1,
#  ('diventare', 'razzisti'): 2,
#  ('diventare', 'peggio'): 3,
#  ('razzisti', 'peggio'): 12,
#  ('meditate', 'sinistronzi'): 2,
#  ('tolleranza', 'rispetta'): 1,
#  ('tolleranza', 'cultura'): 1,
#  ('tolleranza', 'legge'): 4,
#  ('tolleranza', 'barcone'): 1,
#  ('tolleranza', 'via'): 1,
#  ('rispetta', 'cultura'): 2,
#  ('rispetta', 'legge'): 2,
#  ('rispetta', 'barcone'): 1,
#  ('rispetta', 'via'): 1,
#  ('cultura', 'legge'): 5,
#  ('cultura', 'barcone'): 1,
#  ('cultura', 'via'): 3,
#  ('legge', 'barcone'): 2,
#  ('legge', 'via'): 24,
#  ('barcone', 'via'): 4,
#  ('papa', 'francesco'): 59,
#  ('papa', 'giudichi'): 1,
#  ('papa', 'fatto'): 25,
#  ('papa', 'sicuro'): 3,
#  ('papa', 'debbano'): 1,
#  ('papa', 'baciare'): 2,
#  ('papa', 'piedi'): 11,
#  ('papa', 'possibili'): 1,
#  ('papa', 'aguzzini'): 1,
#  ('francesco', 'giudichi'): 1,
#  ('francesco', 'fatto'): 11,
#  ('francesco', 'sicuro'): 3,
#  ('francesco', 'debbano'): 1,
#  ('francesco', 'baciare'): 1,
#  ('francesco', 'piedi'): 4,
#  ('francesco', 'possibili'): 1,
#  ('francesco', 'aguzzini'): 1,
#  ('giudichi', 'fatto'): 3,
#  ('giudichi', 'sicuro'): 1,
#  ('giudichi', 'debbano'): 1,
#  ('giudichi', 'baciare'): 1,
#  ('giudichi', 'piedi'): 1,
#  ('giudichi', 'possibili'): 1,
#  ('giudichi', 'aguzzini'): 1,
#  ('fatto', 'sicuro'): 21,
#  ('fatto', 'debbano'): 4,
#  ('fatto', 'baciare'): 1,
#  ('fatto', 'piedi'): 7,
#  ('fatto', 'possibili'): 7,
#  ('fatto', 'aguzzini'): 1,
#  ('sicuro', 'debbano'): 1,
#  ('sicuro', 'baciare'): 1,
#  ('sicuro', 'piedi'): 3,
#  ('sicuro', 'possibili'): 1,
#  ('sicuro', 'aguzzini'): 1,
#  ('debbano', 'baciare'): 1,
#  ('debbano', 'piedi'): 1,
#  ('debbano', 'possibili'): 1,
#  ('debbano', 'aguzzini'): 1,
#  ('baciare', 'piedi'): 4,
#  ('baciare', 'possibili'): 1,
#  ('baciare', 'aguzzini'): 1,
#  ('piedi', 'possibili'): 1,
#  ('piedi', 'aguzzini'): 1,
#  ('possibili', 'aguzzini'): 1,
#  ('occhio', 'inghilterra'): 1,
#  ('occhio', 'governano'): 1,
#  ('occhio', 'lorsignori'): 1,
#  ('occhio', 'lotta'): 1,
#  ('occhio', 'conquista'): 1,
#  ('occhio', 'sfogliare'): 1,
#  ('occhio', 'corano'): 4,
#  ('occhio', 'silenziosa'): 1,
#  ('occhio', 'diventera'): 1,
#  ('occhio', 'sempre'): 22,
#  ('occhio', 'rumorosa'): 1,
#  ('occhio', 'cominciano'): 1,
#  ('occhio', 'numeri'): 1,
#  ('occhio', 'grazie'): 4,
#  ('occhio', 'politiche'): 3,
#  ('occhio', 'stolte'): 1,
#  ('occhio', 'miopi'): 1,
#  ('inghilterra', 'governano'): 1,
#  ('inghilterra', 'lorsignori'): 1,
#  ('inghilterra', 'lotta'): 1,
#  ('inghilterra', 'conquista'): 1,
#  ('inghilterra', 'sfogliare'): 1,
#  ('inghilterra', 'corano'): 1,
#  ('inghilterra', 'silenziosa'): 1,
#  ('inghilterra', 'diventera'): 1,
#  ('inghilterra', 'sempre'): 6,
#  ('inghilterra', 'rumorosa'): 1,
#  ('inghilterra', 'cominciano'): 1,
#  ('inghilterra', 'numeri'): 1,
#  ('inghilterra', 'grazie'): 1,
#  ('inghilterra', 'politiche'): 1,
#  ('inghilterra', 'stolte'): 1,
#  ('inghilterra', 'miopi'): 1,
#  ('governano', 'lorsignori'): 1,
#  ('governano', 'lotta'): 1,
#  ('governano', 'conquista'): 1,
#  ('governano', 'sfogliare'): 1,
#  ('governano', 'corano'): 1,
#  ('governano', 'silenziosa'): 1,
#  ('governano', 'diventera'): 1,
#  ('governano', 'sempre'): 3,
#  ('governano', 'rumorosa'): 1,
#  ('governano', 'cominciano'): 1,
#  ('governano', 'numeri'): 1,
#  ('governano', 'grazie'): 2,
#  ('governano', 'politiche'): 1,
#  ('governano', 'stolte'): 1,
#  ('governano', 'miopi'): 1,
#  ('lorsignori', 'lotta'): 1,
#  ('lorsignori', 'conquista'): 1,
#  ('lorsignori', 'sfogliare'): 1,
#  ('lorsignori', 'corano'): 1,
#  ('lorsignori', 'silenziosa'): 1,
#  ('lorsignori', 'diventera'): 1,
#  ('lorsignori', 'sempre'): 1,
#  ('lorsignori', 'rumorosa'): 1,
#  ('lorsignori', 'cominciano'): 1,
#  ('lorsignori', 'numeri'): 1,
#  ('lorsignori', 'grazie'): 1,
#  ('lorsignori', 'politiche'): 1,
#  ('lorsignori', 'stolte'): 1,
#  ('lorsignori', 'miopi'): 1,
#  ('lotta', 'conquista'): 1,
#  ('lotta', 'sfogliare'): 1,
#  ('lotta', 'corano'): 1,
#  ('lotta', 'silenziosa'): 1,
#  ('lotta', 'diventera'): 1,
#  ('lotta', 'sempre'): 10,
#  ('lotta', 'rumorosa'): 1,
#  ('lotta', 'cominciano'): 1,
#  ('lotta', 'numeri'): 1,
#  ('lotta', 'grazie'): 9,
#  ('lotta', 'politiche'): 2,
#  ('lotta', 'stolte'): 1,
#  ('lotta', 'miopi'): 1,
#  ('conquista', 'sfogliare'): 1,
#  ('conquista', 'corano'): 1,
#  ('conquista', 'silenziosa'): 1,
#  ('conquista', 'diventera'): 1,
#  ('conquista', 'sempre'): 9,
#  ('conquista', 'rumorosa'): 1,
#  ('conquista', 'cominciano'): 1,
#  ('conquista', 'numeri'): 1,
#  ('conquista', 'grazie'): 1,
#  ('conquista', 'politiche'): 1,
#  ('conquista', 'stolte'): 1,
#  ('conquista', 'miopi'): 1,
#  ('sfogliare', 'corano'): 1,
#  ('sfogliare', 'silenziosa'): 1,
#  ('sfogliare', 'diventera'): 1,
#  ('sfogliare', 'sempre'): 1,
#  ('sfogliare', 'rumorosa'): 1,
#  ('sfogliare', 'cominciano'): 1,
#  ('sfogliare', 'numeri'): 1,
#  ('sfogliare', 'grazie'): 1,
#  ('sfogliare', 'politiche'): 1,
#  ('sfogliare', 'stolte'): 1,
#  ('sfogliare', 'miopi'): 1,
#  ('corano', 'silenziosa'): 1,
#  ('corano', 'diventera'): 1,
#  ('corano', 'sempre'): 1,
#  ('corano', 'rumorosa'): 1,
#  ('corano', 'cominciano'): 1,
#  ('corano', 'numeri'): 1,
#  ('corano', 'grazie'): 2,
#  ('corano', 'politiche'): 1,
#  ('corano', 'stolte'): 1,
#  ('corano', 'miopi'): 1,
#  ('silenziosa', 'diventera'): 2,
#  ('silenziosa', 'sempre'): 2,
#  ('silenziosa', 'rumorosa'): 2,
#  ('silenziosa', 'cominciano'): 1,
#  ('silenziosa', 'numeri'): 1,
#  ('silenziosa', 'grazie'): 1,
#  ('silenziosa', 'politiche'): 1,
#  ('silenziosa', 'stolte'): 1,
#  ('silenziosa', 'miopi'): 1,
#  ('diventera', 'sempre'): 2,
#  ('diventera', 'rumorosa'): 2,
#  ('diventera', 'cominciano'): 1,
#  ('diventera', 'numeri'): 1,
#  ('diventera', 'grazie'): 3,
#  ('diventera', 'politiche'): 1,
#  ('diventera', 'stolte'): 1,
#  ('diventera', 'miopi'): 1,
#  ('sempre', 'rumorosa'): 1,
#  ('sempre', 'cominciano'): 4,
#  ('sempre', 'numeri'): 12,
#  ('sempre', 'grazie'): 244,
#  ('sempre', 'politiche'): 52,
#  ('sempre', 'stolte'): 1,
#  ('sempre', 'miopi'): 1,
#  ('rumorosa', 'cominciano'): 1,
#  ('rumorosa', 'numeri'): 1,
#  ('rumorosa', 'grazie'): 1,
#  ('rumorosa', 'politiche'): 1,
#  ('rumorosa', 'stolte'): 1,
#  ('rumorosa', 'miopi'): 1,
#  ('cominciano', 'numeri'): 1,
#  ('cominciano', 'grazie'): 1,
#  ('cominciano', 'politiche'): 1,
#  ('cominciano', 'stolte'): 1,
#  ('cominciano', 'miopi'): 1,
#  ('numeri', 'grazie'): 9,
#  ('numeri', 'politiche'): 3,
#  ('numeri', 'stolte'): 1,
#  ('numeri', 'miopi'): 2,
#  ('grazie', 'politiche'): 20,
#  ('grazie', 'stolte'): 1,
#  ('grazie', 'miopi'): 1,
#  ('politiche', 'stolte'): 1,
#  ('politiche', 'miopi'): 1,
#  ('stolte', 'miopi'): 1,
#  ('corrado', 'creare'): 1,
#  ('corrado', 'centro'): 1,
#  ('corrado', 'raccolta'): 1,
#  ('corrado', 'rispedirli'): 1,
#  ('corrado', 'indietro'): 1,
#  ('armeri', 'creare'): 1,
#  ('armeri', 'centro'): 1,
#  ('armeri', 'raccolta'): 1,
#  ('armeri', 'rispedirli'): 1,
#  ('armeri', 'indietro'): 1,
#  ('creare', 'centro'): 4,
#  ('creare', 'raccolta'): 1,
#  ('creare', 'rispedirli'): 1,
#  ('creare', 'indietro'): 2,
#  ('centro', 'raccolta'): 2,
#  ('centro', 'rispedirli'): 1,
#  ('centro', 'indietro'): 4,
#  ('raccolta', 'rispedirli'): 1,
#  ('raccolta', 'indietro'): 1,
#  ('rispedirli', 'indietro'): 1,
#  ('senatore', 'iniziare'): 1,
#  ('senatore', 'dire'): 11,
#  ('senatore', 'verita'): 1,
#  ('senatore', 'islam'): 1,
#  ('senatore', 'pacifico'): 1,
#  ('senatore', 'vertici'): 1,
#  ('senatore', 'chiesa'): 1,
#  ('senatore', 'cattolica'): 1,
#  ('senatore', 'pensano'): 1,
#  ('senatore', 'diversamente'): 1,
#  ('senatore', 'paura'): 1,
#  ('senatore', 'parlare'): 5,
#  ('senatore', 'terrorismo'): 1,
#  ('senatore', 'matrice'): 1,
#  ('senatore', 'islamica'): 1,
#  ('iniziare', 'dire'): 7,
#  ('iniziare', 'verita'): 1,
#  ('iniziare', 'islam'): 1,
#  ('iniziare', 'pacifico'): 1,
#  ('iniziare', 'vertici'): 1,
#  ('iniziare', 'chiesa'): 1,
#  ('iniziare', 'cattolica'): 1,
#  ('iniziare', 'pensano'): 3,
#  ('iniziare', 'diversamente'): 1,
#  ('iniziare', 'paura'): 1,
#  ('iniziare', 'parlare'): 7,
#  ('iniziare', 'terrorismo'): 1,
#  ('iniziare', 'matrice'): 1,
#  ('iniziare', 'islamica'): 1,
#  ('dire', 'verita'): 34,
#  ('dire', 'islam'): 4,
#  ('dire', 'pacifico'): 1,
#  ('dire', 'vertici'): 2,
#  ('dire', 'chiesa'): 6,
#  ('dire', 'cattolica'): 2,
#  ('dire', 'pensano'): 9,
#  ('dire', 'diversamente'): 3,
#  ('dire', 'paura'): 13,
#  ('dire', 'parlare'): 50,
#  ('dire', 'terrorismo'): 2,
#  ('dire', 'matrice'): 1,
#  ('dire', 'islamica'): 1,
#  ('verita', 'islam'): 2,
#  ('verita', 'pacifico'): 1,
#  ('verita', 'vertici'): 1,
#  ('verita', 'chiesa'): 2,
#  ('verita', 'cattolica'): 1,
#  ('verita', 'pensano'): 1,
#  ('verita', 'diversamente'): 2,
#  ('verita', 'paura'): 6,
#  ('verita', 'parlare'): 17,
#  ('verita', 'terrorismo'): 1,
#  ('verita', 'matrice'): 1,
#  ('verita', 'islamica'): 1,
#  ('islam', 'pacifico'): 1,
#  ('islam', 'vertici'): 1,
#  ('islam', 'chiesa'): 3,
#  ('islam', 'cattolica'): 3,
#  ('islam', 'pensano'): 1,
#  ('islam', 'diversamente'): 1,
#  ('islam', 'paura'): 1,
#  ('islam', 'parlare'): 4,
#  ('islam', 'terrorismo'): 3,
#  ('islam', 'matrice'): 1,
#  ('islam', 'islamica'): 7,
#  ('pacifico', 'vertici'): 1,
#  ('pacifico', 'chiesa'): 1,
#  ('pacifico', 'cattolica'): 1,
#  ('pacifico', 'pensano'): 1,
#  ('pacifico', 'diversamente'): 1,
#  ('pacifico', 'paura'): 1,
#  ('pacifico', 'parlare'): 1,
#  ('pacifico', 'terrorismo'): 1,
#  ('pacifico', 'matrice'): 1,
#  ('pacifico', 'islamica'): 1,
#  ('vertici', 'chiesa'): 1,
#  ('vertici', 'cattolica'): 1,
#  ('vertici', 'pensano'): 1,
#  ('vertici', 'diversamente'): 1,
#  ('vertici', 'paura'): 1,
#  ('vertici', 'parlare'): 2,
#  ('vertici', 'terrorismo'): 1,
#  ('vertici', 'matrice'): 2,
#  ('vertici', 'islamica'): 1,
#  ('chiesa', 'cattolica'): 25,
#  ('chiesa', 'pensano'): 1,
#  ('chiesa', 'diversamente'): 1,
#  ('chiesa', 'paura'): 4,
#  ('chiesa', 'parlare'): 2,
#  ('chiesa', 'terrorismo'): 1,
#  ('chiesa', 'matrice'): 1,
#  ('chiesa', 'islamica'): 3,
#  ('cattolica', 'pensano'): 1,
#  ('cattolica', 'diversamente'): 1,
#  ('cattolica', 'paura'): 1,
#  ('cattolica', 'parlare'): 1,
#  ('cattolica', 'terrorismo'): 1,
#  ('cattolica', 'matrice'): 1,
#  ('cattolica', 'islamica'): 1,
#  ('pensano', 'diversamente'): 5,
#  ('pensano', 'paura'): 4,
#  ('pensano', 'parlare'): 5,
#  ('pensano', 'terrorismo'): 1,
#  ('pensano', 'matrice'): 1,
#  ('pensano', 'islamica'): 1,
#  ('diversamente', 'paura'): 2,
#  ('diversamente', 'parlare'): 2,
#  ('diversamente', 'terrorismo'): 1,
#  ('diversamente', 'matrice'): 1,
#  ('diversamente', 'islamica'): 1,
#  ('paura', 'parlare'): 14,
#  ('paura', 'terrorismo'): 1,
#  ('paura', 'matrice'): 2,
#  ('paura', 'islamica'): 1,
#  ('parlare', 'terrorismo'): 2,
#  ('parlare', 'matrice'): 1,
#  ('parlare', 'islamica'): 2,
#  ('terrorismo', 'matrice'): 1,
#  ('terrorismo', 'islamica'): 1,
#  ('matrice', 'islamica'): 4,
#  ('buonisti', 'comunisti'): 1,
#  ('buonisti', 'trasferta'): 1,
#  ('buonisti', 'trovarli'): 1,
#  ('buonisti', 'possibilmente'): 1,
#  ('buonisti', 'rimanerci'): 1,
#  ('comunisti', 'trasferta'): 1,
#  ('comunisti', 'trovarli'): 1,
#  ('comunisti', 'possibilmente'): 2,
#  ('comunisti', 'rimanerci'): 1,
#  ('trasferta', 'trovarli'): 1,
#  ('trasferta', 'possibilmente'): 1,
#  ('trasferta', 'rimanerci'): 1,
#  ('trovarli', 'possibilmente'): 1,
#  ('trovarli', 'rimanerci'): 1,
#  ('possibilmente', 'rimanerci'): 1,
#  ('gemmato', 'colgo'): 1,
#  ...}

# %%
##obtain weighted edges list
##edge lists =36million
#WEIGHTED
#to get weighted graph we need a list of 3-element tuplels (u,v,w) where u and v are nodes 
## and w is a number representing weight

words_weighted = []
for edge in words_projection:
    words_weighted.append((edge[0],edge[1],words_projection[edge]))

G = nx.Graph()
G.add_weighted_edges_from(words_weighted)

print(G.edges)
print(G.nodes)

nx.write_weighted_edgelist(G, "New_weighted_edges.csv",delimiter=",") ##save the edges list as csv
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
##load the edges list
edges_list = pd.read_csv('New_weighted_edges.csv')
df_edges = pd.DataFrame(data = edges_list)
df_edges.head()
# Out:
#    dire        gente  60
# 0  dire       guerra  23
# 1  dire      portata   3
# 2  dire         casa  79
# 3  dire  rimpatriati   3
# 4  dire     senatore  11

# %%
df_edges.loc[-1] = ["dire", "gente",60]  # adding a row
df_edges.index = df_edges.index + 1  # shifting index
df_edges = df_edges.sort_index()

# %%
df_edges.head()
# Out:
#    dire        gente  60
# 0  dire        gente  60
# 1  dire       guerra  23
# 2  dire      portata   3
# 3  dire         casa  79
# 4  dire  rimpatriati   3

# %%
df_edges.columns = ["source", "target", "weight"]
df_edges.head()
# Out:
#   source       target  weight
# 0   dire        gente      60
# 1   dire       guerra      23
# 2   dire      portata       3
# 3   dire         casa      79
# 4   dire  rimpatriati       3

# %%
df_edges.shape
# Out:
# (3692282, 3)

# %%
###use this as your list of edges
df_edges.to_csv("New_Edges.csv", index = False)

# %%
##lets create a node list
###nodes list = 57419
nl_df = pd.DataFrame.from_dict(unique_words,orient="index")
nl_df.reset_index(inplace=True)
nl_df[0] = nl_df['index']
nl_df.rename(columns={"index":"Id", 0:"Label"},inplace=True)


nl_df.to_csv("New_Nodes_list.csv",index=False)
