# %%
##import the libraries
import pandas as pd 
import numpy as np
import os
import pickle
import networkx as nx
import itertools
from itertools import combinations

import statsmodels
import statsmodels.api as sm
import scipy.stats as stats

import matplotlib.pyplot as plt

# %% [markdown]
# **Load Clean Comments and create a data frame**

# %%
##load the cleaned comments and convert them to a data frame
#df['text_cleaned'] = pd.read_pickle(os.path.join(your_dir, 'comments_cleaned'))

clean_comments = pd.read_pickle('comments_cleaned')
df = pd.DataFrame(data = clean_comments)

##insert a column to indicate unique id
df['ID'] = range(0, 0+len(df))
cols = list(df.columns) ##column list
cols = [cols[-1]] + cols[:-1]  #make last column first
df=df[cols]
df.head()
# Out:
#    ID                                         text_clean
# 0   0              gente guerra portato casa rimpatriare
# 1   1                                 marcello perfavore
# 2   2  patria patriota difesa radice soccombere roma ...
# 3   3                           musulmano comandare casa
# 4   4                odio dipendere odio comandare libro

# %%
##lets construct a matrix of the unique words
##first lets save to csv
df.to_csv("clean_comments.csv",header=True,index=False)

# %%
len(df.index) ##count of rows
# Out:
# 78174

# %%
#for index, row in df.iterrows():
 # print(len(row["text_clean"])) ##eg lrn of row 1 = 158

 ## print(row["text_clean"]) ##we obtain the rows of column text_clean

  ##DataFrame.iterrows is a generator which yields both the index and row (as a Series):
##DataFrame.to_string() - to print the data frame

# %%
###create a copy of the original data frame
df_clean = df.copy()
df_clean.head()
# Out:
#    ID                                         text_clean
# 0   0              gente guerra portato casa rimpatriare
# 1   1                                 marcello perfavore
# 2   2  patria patriota difesa radice soccombere roma ...
# 3   3                           musulmano comandare casa
# 4   4                odio dipendere odio comandare libro

# %%
words_per_comment = {}
for index, row in df_clean.iterrows():
  words_per_comment[row["ID"]]= [clean_txt for clean_txt in row["text_clean"]]

# %%
print(len(words_per_comment))
# Out:
# 78174

# %% [markdown]
# **This tokenizes the cleaned text to words using NLTK**

# %%
##tokenize the text ie split the text to words 
##df_words['text_clean'].apply(lambda x: ' '.join(x)) - to join the words

import nltk
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
df_words = df.copy() ##create a copy of the original data frame
df_words['text_clean'] = df['text_clean'].apply(lambda s: tokenizer.tokenize(s))
df_words.head(20)
# Out:
#     ID                                         text_clean
# 0    0        [gente, guerra, portato, casa, rimpatriare]
# 1    1                              [marcello, perfavore]
# 2    2  [patria, patriota, difesa, radice, soccombere,...
# 3    3                       [musulmano, comandare, casa]
# 4    4          [odio, dipendere, odio, comandare, libro]
# 5    5                                         [razzista]
# 6    6                  [meditato, sinistronzi, meditato]
# 7    7  [tolleranza, rispettare, cultura, legge, barcone]
# 8    8                                    [sottoscrivere]
# 9    9  [papa, francesco, giudicare, sicuro, baciare, ...
# 10  10  [occhio, inghilterra, governare, lorsignori, l...
# 11  11  [corrado, armeri, creare, centro, raccolto, ri...
# 12  12  [senatore, iniziare, verita, islam, pacifico, ...
# 13  13  [buonista, comunista, trasferta, trovarli, pos...
# 14  14  [on, gemmare, cogliere, occasione, rammentare,...
# 15  15                                [escremento, umano]
# 16  16  [infilare, culetto, antifa, suppostina, figlio...
# 17  17         [pezzo, merda, italia, schifare, italiano]
# 18  18  [lurido, escremento, putrefare, anti, italiano...
# 19  19  [portare, ettaro, ettaro, terreno, alloggiare,...

# %%
##how to get the unique words in a data frame
##this is an array of all the unique words in the clean comments

df_unique = df_words["text_clean"].apply(pd.Series).stack().unique()
df_unique.shape ## we have 43041 unique words
# Out:
# (42628,)

# %% [markdown]
# **Create Edges lists and Node list**

# %%
##try this way to visualize the unique words
## create a dictionary of unique words

unique_words = {}
words_per_comment = {}

for index, row in df_words.iterrows():  ##iterating over the df
  if(len(row["text_clean"])>0):  ##this gives the length of each row
    words_per_comment[row["ID"]]= [clean_txt for clean_txt in row["text_clean"]] ###iterating the column text_clean. There are 78174 rows
    for clean_txt in row["text_clean"]:
      unique_words.setdefault(clean_txt, 0) ## setdefault() method returns the value of a key (if the key is in dictionary)
      unique_words[clean_txt] += 1

#setdefault()
#Returns: 
#Value of the key if it is in the dictionary. 
#None if key is not in the dictionary and default_value is not specified. 
#default_value if key is not in the dictionary and default_value is specified.

# %%
print(len(unique_words))
# Out:
# 42628

# %%
print(unique_words)
# Out:
# {'gente': 1323, 'guerra': 568, 'portato': 117, 'casa': 1545, 'rimpatriare': 65, 'marcello': 146, 'perfavore': 12, 'patria': 203, 'patriota': 25, 'difesa': 237, 'radice': 68, 'soccombere': 2, 'roma': 592, 'islamico': 189, 'accoltellare': 11, 'crocifisso': 44, 'collo': 25, 'accadere': 141, 'stazione': 37, 'termine': 149, 'aggressore': 6, 'fermare': 205, 'poliziotto': 69, 'notare': 153, 'vittima': 136, 'bus': 15, 'tentare': 88, 'sgozzarlo': 1, 'aumentare': 522, 'controllo': 51, 'attenzione': 158, 'prevenire': 13, 'violenza': 235, 'cittadino': 711, 'innocente': 85, 'imperativo': 4, 'corrado': 23, 'armeri': 2, 'fdi': 75, 'musulmano': 144, 'comandare': 181, 'odio': 381, 'dipendere': 155, 'libro': 290, 'razzista': 348, 'meditato': 26, 'sinistronzi': 21, 'tolleranza': 59, 'rispettare': 785, 'cultura': 279, 'legge': 1058, 'barcone': 76, 'sottoscrivere': 45, 'papa': 310, 'francesco': 250, 'giudicare': 107, 'sicuro': 417, 'baciare': 96, 'piede': 185, 'aguzzino': 6, 'occhio': 344, 'inghilterra': 16, 'governare': 512, 'lorsignori': 1, 'lotta': 157, 'conquistare': 56, 'sfogliare': 1, 'corano': 9, 'silenzioso': 9, 'diventera': 15, 'rumoroso': 4, 'cominciare': 259, 'numero': 116, 'politico': 2868, 'stolto': 18, 'miope': 13, 'creare': 395, 'centro': 429, 'raccolto': 48, 'rispedirli': 2, 'indietro': 148, 'senatore': 58, 'iniziare': 315, 'verita': 373, 'islam': 101, 'pacifico': 24, 'vertice': 41, 'chiesa': 271, 'cattolico': 94, 'pensare': 1016, 'diversamente': 72, 'paura': 358, 'parlare': 2658, 'terrorismo': 42, 'matrice': 13, 'buonista': 155, 'comunista': 570, 'trasferta': 7, 'trovarli': 4, 'possibilmente': 15, 'rimanerci': 5, 'on': 129, 'gemmare': 20, 'cogliere': 39, 'occasione': 156, 'rammentare': 10, 'proposta': 266, 'attuale': 200, 'pertinente': 6, 'compreso': 85, 'situazione': 282, 'italia': 3702, 'migliorare': 200, 'fronte': 150, 'cordiale': 23, 'saluto': 299, 'escremento': 11, 'umano': 317, 'infilare': 20, 'culetto': 4, 'antifa': 4, 'suppostina': 1, 'figlio': 475, 'brigatista': 8, 'assassino': 98, 'pezzo': 187, 'merda': 593, 'schifare': 427, 'italiano': 3571, 'lurido': 36, 'putrefare': 3, 'anti': 97, 'servo': 58, 'pd': 2640, 'sinistroidi': 53, 'feccia': 98, 'umanita': 132, 'vergognatevi': 135, 'portare': 870, 'ettaro': 7, 'terreno': 38, 'alloggiare': 14, 'big': 20, 'villa': 32, 'chimico': 83, 'castrare': 27, 'bello': 1627, 'colpo': 96, 'forbice': 6, 'castrazione': 94, 'traumatico': 1, 'curare': 150, 'ricostituire': 5, 'calcio': 96, 'condividere': 469, 'accetta': 2, 'fisico': 66, 'galera': 248, 'chirurgico': 14, 'bufala': 122, 'unico': 881, 'carabiniere': 94, 'ordine': 325, 'picchiare': 53, 'insultare': 164, 'minacciare': 84, 'ridicolo': 329, 'capovolgere': 9, 'regola': 136, 'vivere': 630, 'civile': 268, 'razza': 100, 'asociale': 2, 'clandestino': 321, 'delinquente': 325, 'comune': 364, 'permettere': 402, 'qualsiasi': 233, 'magistratura': 155, 'vergognoso': 257, 'realta': 347, 'impunito': 20, 'garantito': 20, 'vergognare': 543, 'ridurre': 250, 'errare': 18, 'oltraggiare': 11, 'pubblicare': 350, 'ufficiale': 71, 'osare': 29, 'ribellarsi': 3, 'confronto': 131, 'rappresentante': 117, 'invertito': 6, 'guaio': 66, 'tutorio': 4, 'sfiorare': 12, 'gentaglia': 67, 'specie': 100, 'bianco': 158, 'nero': 302, 'farsi': 244, 'massacrare': 92, 'rifiuto': 55, 'societa': 173, 'amato': 50, 'coccolato': 1, 'entrare': 644, 'quantita': 26, 'incontrollato': 16, 'cavolo': 116, 'amaro': 42, 'ben': 434, 'lezione': 87, 'teaser': 3, 'spaccategli': 1, 'sedere': 99, 'gentile': 99, 'spaccare': 28, 'bastardo': 169, 'tornare': 324, 'cammello': 4, 'servire': 640, 'volante': 4, 'agente': 46, 'sparare': 256, 'volere': 1189, 'taser': 9, 'applicare': 91, 'ingaggiare': 16, 'polizia': 174, 'americano': 102, 'ovvero': 57, 'piantargli': 1, 'pallottola': 6, 'cal': 2, 'accennare': 16, 'reazione': 46, 'episodio': 57, 'carcere': 103, 'duro': 251, 'bestia': 139, 'salvini': 3407, 'autorizzare': 43, 'uso': 209, 'immigrato': 262, 'sapere': 2593, 'incontrare': 143, 'scarcerare': 63, 'giu ...

# %%
##We can use this way to visualize matrix of unique words
##The words dont appear twice hence the value = 0/1

clean_df = pd.DataFrame(0, index=unique_words, columns=unique_words)

for key in words_per_comment:
  for pair in itertools.product(words_per_comment[key],words_per_comment[key]):
    if pair[0]!=pair[1] and not(clean_df.at[pair[0],pair[1]]):
      clean_df.at[pair[0],pair[1]] += 1
      clean_df.at[pair[1],pair[0]] += 1

# %%
display(clean_df) ##this is the full matrix of
# Out:
#                   gente  guerra  portato  casa  rimpatriare  marcello  \
# gente                 0       1        1     1            1         1
# guerra                1       0        1     1            1         0
# portato               1       1        0     1            1         0
# casa                  1       1        1     0            1         1
# rimpatriare           1       1        1     1            0         0
# ...                 ...     ...      ...   ...          ...       ...
# x91                   0       0        0     0            0         0
# satanasso             0       0        0     0            0         0
# parlamentari          0       0        0     0            0         0
# consigliatissima      0       0        0     0            0         0
# fdo                   0       0        0     0            0         0
#
#                   perfavore  patria  patriota  difesa  ...  quellivche  \
# gente                     0       1         1       1  ...           0
# guerra                    0       1         0       1  ...           0
# portato                   0       1         0       1  ...           0
# casa                      0       1         1       1  ...           0
# rimpatriare               0       0         0       0  ...           0
# ...                     ...     ...       ...     ...  ...         ...
# x91                       0       0         0       0  ...           0
# satanasso                 0       0         0       0  ...           0
# parlamentari              0       0         0       0  ...           0
# consigliatissima          0       0         0       0  ...           0
# fdo                       0       0         0       0  ...           0
#
#                   ndrine  earth  xab  x88  x91  satanasso  parlamentari  \
# gente                  0      0    0    0    0          0             0
# guerra                 0      0    0    0    0          0             0
# portato                0      0    0    0    0          0             0
# casa                   0      0    0    0    0          0             0
# rimpatriare            0      0    0    0    0          0             0
# ...                  ...    ...  ...  ...  ...        ...           ...
# x91                    0      1    1    1    0          0             0
# satanasso              0      0    0    0    0          0             1
# parlamentari           0      0    0    0    0          1             0
# consigliatissima       0      0    0    0    0          0             0
# fdo                    0      0    0    0    0          0             0
#
#                   consigliatissima  fdo
# gente                            0    0
# guerra                           0    0
# portato                          0    0
# casa                             0    0
# rimpatriare                      0    0
# ...                            ...  ...
# x91                              0    0
# satanasso                        0    0
# parlamentari                     0    0
# consigliatissima                 0    0
# fdo                              0    0
#
# [42628 rows x 42628 columns]

# %%
##use this as a basis to get edges and their weights
words_projection = {} ##create dictionary 
##itertools.product() which computes the cartesian product of input iterables.

for key in words_per_comment:
    for pair in itertools.product(words_per_comment[key],words_per_comment[key]):
        if pair[0]!=pair[1] and not(pair[::-1] in words_projection):
            words_projection.setdefault(pair,0)
            words_projection[pair] += 1

words_projection
# Out:
# {('gente', 'guerra'): 11,
#  ('gente', 'portato'): 7,
#  ('gente', 'casa'): 75,
#  ('gente', 'rimpatriare'): 4,
#  ('guerra', 'portato'): 9,
#  ('guerra', 'casa'): 38,
#  ('guerra', 'rimpatriare'): 3,
#  ('portato', 'casa'): 16,
#  ('portato', 'rimpatriare'): 2,
#  ('casa', 'rimpatriare'): 4,
#  ('marcello', 'perfavore'): 1,
#  ('patria', 'patriota'): 2,
#  ('patria', 'difesa'): 6,
#  ('patria', 'radice'): 2,
#  ('patria', 'soccombere'): 1,
#  ('patria', 'roma'): 5,
#  ('patria', 'islamico'): 8,
#  ('patria', 'accoltellare'): 1,
#  ('patria', 'crocifisso'): 1,
#  ('patria', 'collo'): 1,
#  ('patria', 'accadere'): 5,
#  ('patria', 'stazione'): 1,
#  ('patria', 'termine'): 8,
#  ('patria', 'aggressore'): 1,
#  ('patria', 'fermare'): 3,
#  ('patria', 'poliziotto'): 1,
#  ('patria', 'notare'): 3,
#  ('patria', 'vittima'): 4,
#  ('patria', 'bus'): 1,
#  ('patria', 'tentare'): 1,
#  ('patria', 'sgozzarlo'): 1,
#  ('patria', 'aumentare'): 5,
#  ('patria', 'controllo'): 1,
#  ('patria', 'attenzione'): 1,
#  ('patria', 'prevenire'): 1,
#  ('patria', 'violenza'): 2,
#  ('patria', 'cittadino'): 57,
#  ('patria', 'innocente'): 1,
#  ('patria', 'imperativo'): 1,
#  ('patria', 'corrado'): 1,
#  ('patria', 'armeri'): 1,
#  ('patria', 'fdi'): 2,
#  ('patriota', 'difesa'): 1,
#  ('patriota', 'radice'): 1,
#  ('patriota', 'soccombere'): 1,
#  ('patriota', 'roma'): 6,
#  ('patriota', 'islamico'): 2,
#  ('patriota', 'accoltellare'): 1,
#  ('patriota', 'crocifisso'): 1,
#  ('patriota', 'collo'): 1,
#  ('patriota', 'accadere'): 1,
#  ('patriota', 'stazione'): 1,
#  ('patriota', 'termine'): 1,
#  ('patriota', 'aggressore'): 1,
#  ('patriota', 'fermare'): 1,
#  ('patriota', 'poliziotto'): 1,
#  ('patriota', 'notare'): 1,
#  ('patriota', 'vittima'): 1,
#  ('patriota', 'bus'): 1,
#  ('patriota', 'tentare'): 1,
#  ('patriota', 'sgozzarlo'): 1,
#  ('patriota', 'aumentare'): 1,
#  ('patriota', 'controllo'): 1,
#  ('patriota', 'attenzione'): 1,
#  ('patriota', 'prevenire'): 1,
#  ('patriota', 'violenza'): 1,
#  ('patriota', 'cittadino'): 25,
#  ('patriota', 'innocente'): 1,
#  ('patriota', 'imperativo'): 1,
#  ('patriota', 'corrado'): 1,
#  ('patriota', 'armeri'): 1,
#  ('patriota', 'fdi'): 1,
#  ('difesa', 'radice'): 1,
#  ('difesa', 'soccombere'): 1,
#  ('difesa', 'roma'): 11,
#  ('difesa', 'islamico'): 3,
#  ('difesa', 'accoltellare'): 1,
#  ('difesa', 'crocifisso'): 2,
#  ('difesa', 'collo'): 2,
#  ('difesa', 'accadere'): 4,
#  ('difesa', 'stazione'): 1,
#  ('difesa', 'termine'): 2,
#  ('difesa', 'aggressore'): 1,
#  ('difesa', 'fermare'): 4,
#  ('difesa', 'poliziotto'): 1,
#  ('difesa', 'notare'): 9,
#  ('difesa', 'vittima'): 7,
#  ('difesa', 'bus'): 1,
#  ('difesa', 'tentare'): 3,
#  ('difesa', 'sgozzarlo'): 1,
#  ('difesa', 'aumentare'): 4,
#  ('difesa', 'controllo'): 1,
#  ('difesa', 'attenzione'): 5,
#  ('difesa', 'prevenire'): 1,
#  ('difesa', 'violenza'): 8,
#  ('difesa', 'cittadino'): 21,
#  ('difesa', 'innocente'): 7,
#  ('difesa', 'imperativo'): 1,
#  ('difesa', 'corrado'): 1,
#  ('difesa', 'armeri'): 1,
#  ('difesa', 'fdi'): 1,
#  ('radice', 'soccombere'): 1,
#  ('radice', 'roma'): 2,
#  ('radice', 'islamico'): 3,
#  ('radice', 'accoltellare'): 1,
#  ('radice', 'crocifisso'): 1,
#  ('radice', 'collo'): 1,
#  ('radice', 'accadere'): 1,
#  ('radice', 'stazione'): 1,
#  ('radice', 'termine'): 3,
#  ('radice', 'aggressore'): 1,
#  ('radice', 'fermare'): 2,
#  ('radice', 'poliziotto'): 1,
#  ('radice', 'notare'): 1,
#  ('radice', 'vittima'): 1,
#  ('radice', 'bus'): 1,
#  ('radice', 'tentare'): 1,
#  ('radice', 'sgozzarlo'): 1,
#  ('radice', 'aumentare'): 1,
#  ('radice', 'controllo'): 1,
#  ('radice', 'attenzione'): 1,
#  ('radice', 'prevenire'): 2,
#  ('radice', 'violenza'): 2,
#  ('radice', 'cittadino'): 3,
#  ('radice', 'innocente'): 1,
#  ('radice', 'imperativo'): 1,
#  ('radice', 'corrado'): 1,
#  ('radice', 'armeri'): 1,
#  ('radice', 'fdi'): 1,
#  ('soccombere', 'roma'): 2,
#  ('soccombere', 'islamico'): 2,
#  ('soccombere', 'accoltellare'): 1,
#  ('soccombere', 'crocifisso'): 1,
#  ('soccombere', 'collo'): 1,
#  ('soccombere', 'accadere'): 1,
#  ('soccombere', 'stazione'): 1,
#  ('soccombere', 'termine'): 1,
#  ('soccombere', 'aggressore'): 1,
#  ('soccombere', 'fermare'): 1,
#  ('soccombere', 'poliziotto'): 1,
#  ('soccombere', 'notare'): 1,
#  ('soccombere', 'vittima'): 1,
#  ('soccombere', 'bus'): 1,
#  ('soccombere', 'tentare'): 1,
#  ('soccombere', 'sgozzarlo'): 1,
#  ('soccombere', 'aumentare'): 1,
#  ('soccombere', 'controllo'): 1,
#  ('soccombere', 'attenzione'): 1,
#  ('soccombere', 'prevenire'): 1,
#  ('soccombere', 'violenza'): 1,
#  ('soccombere', 'cittadino'): 1,
#  ('soccombere', 'innocente'): 1,
#  ('soccombere', 'imperativo'): 1,
#  ('soccombere', 'corrado'): 1,
#  ('soccombere', 'armeri'): 1,
#  ('soccombere', 'fdi'): 1,
#  ('roma', 'islamico'): 7,
#  ('roma', 'accoltellare'): 2,
#  ('roma', 'crocifisso'): 2,
#  ('roma', 'collo'): 2,
#  ('roma', 'accadere'): 6,
#  ('roma', 'stazione'): 4,
#  ('roma', 'termine'): 11,
#  ('roma', 'aggressore'): 2,
#  ('roma', 'fermare'): 8,
#  ('roma', 'poliziotto'): 3,
#  ('roma', 'notare'): 4,
#  ('roma', 'vittima'): 23,
#  ('roma', 'bus'): 6,
#  ('roma', 'tentare'): 3,
#  ('roma', 'sgozzarlo'): 2,
#  ('roma', 'aumentare'): 15,
#  ('roma', 'controllo'): 2,
#  ('roma', 'attenzione'): 13,
#  ('roma', 'prevenire'): 2,
#  ('roma', 'violenza'): 6,
#  ('roma', 'cittadino'): 47,
#  ('roma', 'innocente'): 4,
#  ('roma', 'imperativo'): 2,
#  ('roma', 'corrado'): 3,
#  ('roma', 'armeri'): 2,
#  ('roma', 'fdi'): 4,
#  ('islamico', 'accoltellare'): 2,
#  ('islamico', 'crocifisso'): 5,
#  ('islamico', 'collo'): 2,
#  ('islamico', 'accadere'): 5,
#  ('islamico', 'stazione'): 2,
#  ('islamico', 'termine'): 4,
#  ('islamico', 'aggressore'): 2,
#  ('islamico', 'fermare'): 5,
#  ('islamico', 'poliziotto'): 2,
#  ('islamico', 'notare'): 7,
#  ('islamico', 'vittima'): 4,
#  ('islamico', 'bus'): 3,
#  ('islamico', 'tentare'): 2,
#  ('islamico', 'sgozzarlo'): 2,
#  ('islamico', 'aumentare'): 3,
#  ('islamico', 'controllo'): 3,
#  ('islamico', 'attenzione'): 2,
#  ('islamico', 'prevenire'): 2,
#  ('islamico', 'violenza'): 14,
#  ('islamico', 'cittadino'): 4,
#  ('islamico', 'innocente'): 3,
#  ('islamico', 'imperativo'): 2,
#  ('islamico', 'corrado'): 2,
#  ('islamico', 'armeri'): 2,
#  ('islamico', 'fdi'): 2,
#  ('accoltellare', 'crocifisso'): 4,
#  ('accoltellare', 'collo'): 2,
#  ('accoltellare', 'accadere'): 1,
#  ('accoltellare', 'stazione'): 1,
#  ('accoltellare', 'termine'): 1,
#  ('accoltellare', 'aggressore'): 1,
#  ('accoltellare', 'fermare'): 1,
#  ('accoltellare', 'poliziotto'): 1,
#  ('accoltellare', 'notare'): 1,
#  ('accoltellare', 'vittima'): 1,
#  ('accoltellare', 'bus'): 1,
#  ('accoltellare', 'tentare'): 3,
#  ('accoltellare', 'sgozzarlo'): 1,
#  ('accoltellare', 'aumentare'): 1,
#  ('accoltellare', 'controllo'): 1,
#  ('accoltellare', 'attenzione'): 1,
#  ('accoltellare', 'prevenire'): 1,
#  ('accoltellare', 'violenza'): 1,
#  ('accoltellare', 'cittadino'): 1,
#  ('accoltellare', 'innocente'): 1,
#  ('accoltellare', 'imperativo'): 1,
#  ('accoltellare', 'corrado'): 1,
#  ('accoltellare', 'armeri'): 1,
#  ('accoltellare', 'fdi'): 1,
#  ('crocifisso', 'collo'): 7,
#  ('crocifisso', 'accadere'): 2,
#  ('crocifisso', 'stazione'): 1,
#  ('crocifisso', 'termine'): 1,
#  ('crocifisso', 'aggressore'): 1,
#  ('crocifisso', 'fermare'): 1,
#  ('crocifisso', 'poliziotto'): 1,
#  ('crocifisso', 'notare'): 1,
#  ('crocifisso', 'vittima'): 1,
#  ('crocifisso', 'bus'): 1,
#  ('crocifisso', 'tentare'): 2,
#  ('crocifisso', 'sgozzarlo'): 1,
#  ('crocifisso', 'aumentare'): 1,
#  ('crocifisso', 'controllo'): 1,
#  ('crocifisso', 'attenzione'): 1,
#  ('crocifisso', 'prevenire'): 1,
#  ('crocifisso', 'violenza'): 4,
#  ('crocifisso', 'cittadino'): 1,
#  ('crocifisso', 'innocente'): 2,
#  ('crocifisso', 'imperativo'): 1,
#  ('crocifisso', 'corrado'): 1,
#  ('crocifisso', 'armeri'): 1,
#  ('crocifisso', 'fdi'): 1,
#  ('collo', 'accadere'): 1,
#  ('collo', 'stazione'): 1,
#  ('collo', 'termine'): 1,
#  ('collo', 'aggressore'): 1,
#  ('collo', 'fermare'): 1,
#  ('collo', 'poliziotto'): 1,
#  ('collo', 'notare'): 1,
#  ('collo', 'vittima'): 1,
#  ('collo', 'bus'): 1,
#  ('collo', 'tentare'): 1,
#  ('collo', 'sgozzarlo'): 1,
#  ('collo', 'aumentare'): 1,
#  ('collo', 'controllo'): 1,
#  ('collo', 'attenzione'): 1,
#  ('collo', 'prevenire'): 1,
#  ('collo', 'violenza'): 1,
#  ('collo', 'cittadino'): 1,
#  ('collo', 'innocente'): 1,
#  ('collo', 'imperativo'): 1,
#  ('collo', 'corrado'): 1,
#  ('collo', 'armeri'): 1,
#  ('collo', 'fdi'): 1,
#  ('accadere', 'stazione'): 2,
#  ('accadere', 'termine'): 3,
#  ('accadere', 'aggressore'): 1,
#  ('accadere', 'fermare'): 2,
#  ('accadere', 'poliziotto'): 2,
#  ('accadere', 'notare'): 1,
#  ('accadere', 'vittima'): 3,
#  ('accadere', 'bus'): 1,
#  ('accadere', 'tentare'): 1,
#  ('accadere', 'sgozzarlo'): 1,
#  ('accadere', 'aumentare'): 4,
#  ('accadere', 'controllo'): 1,
#  ('accadere', 'attenzione'): 1,
#  ('accadere', 'prevenire'): 1,
#  ('accadere', 'violenza'): 4,
#  ('accadere', 'cittadino'): 7,
#  ('accadere', 'innocente'): 3,
#  ('accadere', 'imperativo'): 1,
#  ('accadere', 'corrado'): 1,
#  ('accadere', 'armeri'): 1,
#  ('accadere', 'fdi'): 1,
#  ('stazione', 'termine'): 2,
#  ('stazione', 'aggressore'): 1,
#  ('stazione', 'fermare'): 2,
#  ('stazione', 'poliziotto'): 1,
#  ('stazione', 'notare'): 1,
#  ('stazione', 'vittima'): 1,
#  ('stazione', 'bus'): 1,
#  ('stazione', 'tentare'): 1,
#  ('stazione', 'sgozzarlo'): 1,
#  ('stazione', 'aumentare'): 1,
#  ('stazione', 'controllo'): 1,
#  ('stazione', 'attenzione'): 1,
#  ('stazione', 'prevenire'): 1,
#  ('stazione', 'violenza'): 2,
#  ('stazione', 'cittadino'): 2,
#  ('stazione', 'innocente'): 1,
#  ('stazione', 'imperativo'): 1,
#  ('stazione', 'corrado'): 1,
#  ('stazione', 'armeri'): 1,
#  ('stazione', 'fdi'): 1,
#  ('termine', 'aggressore'): 1,
#  ('termine', 'fermare'): 11,
#  ('termine', 'poliziotto'): 1,
#  ('termine', 'notare'): 8,
#  ('termine', 'vittima'): 7,
#  ('termine', 'bus'): 1,
#  ('termine', 'tentare'): 5,
#  ('termine', 'sgozzarlo'): 1,
#  ('termine', 'aumentare'): 14,
#  ('termine', 'controllo'): 3,
#  ('termine', 'attenzione'): 2,
#  ('termine', 'prevenire'): 1,
#  ('termine', 'violenza'): 1,
#  ('termine', 'cittadino'): 14,
#  ('termine', 'innocente'): 1,
#  ('termine', 'imperativo'): 1,
#  ('termine', 'corrado'): 1,
#  ('termine', 'armeri'): 1,
#  ('termine', 'fdi'): 1,
#  ('aggressore', 'fermare'): 1,
#  ('aggressore', 'poliziotto'): 1,
#  ('aggressore', 'notare'): 1,
#  ('aggressore', 'vittima'): 1,
#  ('aggressore', 'bus'): 1,
#  ('aggressore', 'tentare'): 1,
#  ('aggressore', 'sgozzarlo'): 1,
#  ('aggressore', 'aumentare'): 1,
#  ('aggressore', 'controllo'): 1,
#  ('aggressore', 'attenzione'): 1,
#  ('aggressore', 'prevenire'): 1,
#  ('aggressore', 'violenza'): 1,
#  ('aggressore', 'cittadino'): 1,
#  ('aggressore', 'innocente'): 1,
#  ('aggressore', 'imperativo'): 1,
#  ('aggressore', 'corrado'): 1,
#  ('aggressore', 'armeri'): 1,
#  ('aggressore', 'fdi'): 1,
#  ('fermare', 'poliziotto'): 1,
#  ('fermare', 'notare'): 4,
#  ('fermare', 'vittima'): 1,
#  ('fermare', 'bus'): 1,
#  ('fermare', 'tentare'): 4,
#  ('fermare', 'sgozzarlo'): 1,
#  ('fermare', 'aumentare'): 8,
#  ('fermare', 'controllo'): 2,
#  ('fermare', 'attenzione'): 2,
#  ('fermare', 'prevenire'): 3,
#  ('fermare', 'violenza'): 6,
#  ('fermare', 'cittadino'): 12,
#  ('fermare', 'innocente'): 2,
#  ('fermare', 'imperativo'): 1,
#  ('fermare', 'corrado'): 1,
#  ('fermare', 'armeri'): 1,
#  ('fermare', 'fdi'): 1,
#  ('poliziotto', 'notare'): 1,
#  ('poliziotto', 'vittima'): 2,
#  ('poliziotto', 'bus'): 2,
#  ('poliziotto', 'tentare'): 1,
#  ('poliziotto', 'sgozzarlo'): 1,
#  ('poliziotto', 'aumentare'): 1,
#  ('poliziotto', 'controllo'): 1,
#  ('poliziotto', 'attenzione'): 1,
#  ('poliziotto', 'prevenire'): 2,
#  ('poliziotto', 'violenza'): 1,
#  ('poliziotto', 'cittadino'): 3,
#  ('poliziotto', 'innocente'): 3,
#  ('poliziotto', 'imperativo'): 1,
#  ('poliziotto', 'corrado'): 1,
#  ('poliziotto', 'armeri'): 1,
#  ('poliziotto', 'fdi'): 1,
#  ('notare', 'vittima'): 2,
#  ('notare', 'bus'): 1,
#  ('notare', 'tentare'): 1,
#  ('notare', 'sgozzarlo'): 1,
#  ('notare', 'aumentare'): 5,
#  ('notare', 'controllo'): 1,
#  ('notare', 'attenzione'): 5,
#  ('notare', 'prevenire'): 1,
#  ('notare', 'violenza'): 3,
#  ('notare', 'cittadino'): 5,
#  ('notare', 'innocente'): 5,
#  ('notare', 'imperativo'): 1,
#  ('notare', 'corrado'): 1,
#  ('notare', 'armeri'): 1,
#  ('notare', 'fdi'): 1,
#  ('vittima', 'bus'): 1,
#  ('vittima', 'tentare'): 4,
#  ('vittima', 'sgozzarlo'): 1,
#  ('vittima', 'aumentare'): 3,
#  ('vittima', 'controllo'): 1,
#  ('vittima', 'attenzione'): 3,
#  ('vittima', 'prevenire'): 1,
#  ('vittima', 'violenza'): 24,
#  ('vittima', 'cittadino'): 7,
#  ('vittima', 'innocente'): 7,
#  ('vittima', 'imperativo'): 1,
#  ('vittima', 'corrado'): 1,
#  ('vittima', 'armeri'): 1,
#  ('vittima', 'fdi'): 1,
#  ('bus', 'tentare'): 1,
#  ('bus', 'sgozzarlo'): 1,
#  ('bus', 'aumentare'): 1,
#  ('bus', 'controllo'): 2,
#  ('bus', 'attenzione'): 1,
#  ('bus', 'prevenire'): 1,
#  ('bus', 'violenza'): 1,
#  ('bus', 'cittadino'): 1,
#  ('bus', 'innocente'): 1,
#  ('bus', 'imperativo'): 1,
#  ('bus', 'corrado'): 1,
#  ('bus', 'armeri'): 1,
#  ('bus', 'fdi'): 1,
#  ('tentare', 'sgozzarlo'): 1,
#  ('tentare', 'aumentare'): 3,
#  ('tentare', 'controllo'): 1,
#  ('tentare', 'attenzione'): 3,
#  ('tentare', 'prevenire'): 1,
#  ('tentare', 'violenza'): 8,
#  ('tentare', 'cittadino'): 5,
#  ('tentare', 'innocente'): 1,
#  ('tentare', 'imperativo'): 1,
#  ('tentare', 'corrado'): 1,
#  ('tentare', 'armeri'): 1,
#  ('tentare', 'fdi'): 1,
#  ('sgozzarlo', 'aumentare'): 1,
#  ('sgozzarlo', 'controllo'): 1,
#  ('sgozzarlo', 'attenzione'): 1,
#  ('sgozzarlo', 'prevenire'): 1,
#  ('sgozzarlo', 'violenza'): 1,
#  ('sgozzarlo', 'cittadino'): 1,
#  ('sgozzarlo', 'innocente'): 1,
#  ('sgozzarlo', 'imperativo'): 1,
#  ('sgozzarlo', 'corrado'): 1,
#  ('sgozzarlo', 'armeri'): 1,
#  ('sgozzarlo', 'fdi'): 1,
#  ('aumentare', 'controllo'): 1,
#  ('aumentare', 'attenzione'): 3,
#  ('aumentare', 'prevenire'): 1,
#  ('aumentare', 'violenza'): 4,
#  ('aumentare', 'cittadino'): 23,
#  ('aumentare', 'innocente'): 3,
#  ('aumentare', 'imperativo'): 1,
#  ('aumentare', 'corrado'): 2,
#  ('aumentare', 'armeri'): 1,
#  ('aumentare', 'fdi'): 1,
#  ('controllo', 'attenzione'): 2,
#  ('controllo', 'prevenire'): 1,
#  ('controllo', 'violenza'): 1,
#  ('controllo', 'cittadino'): 1,
#  ('controllo', 'innocente'): 1,
#  ('controllo', 'imperativo'): 1,
#  ('controllo', 'corrado'): 1,
#  ('controllo', 'armeri'): 1,
#  ('controllo', 'fdi'): 1,
#  ('attenzione', 'prevenire'): 1,
#  ('attenzione', 'violenza'): 2,
#  ('attenzione', 'cittadino'): 10,
#  ('attenzione', 'innocente'): 4,
#  ('attenzione', 'imperativo'): 1,
#  ('attenzione', 'corrado'): 1,
#  ('attenzione', 'armeri'): 1,
#  ('attenzione', 'fdi'): 1,
#  ('prevenire', 'violenza'): 3,
#  ('prevenire', 'cittadino'): 3,
#  ('prevenire', 'innocente'): 1,
#  ('prevenire', 'imperativo'): 1,
#  ('prevenire', 'corrado'): 1,
#  ('prevenire', 'armeri'): 1,
#  ('prevenire', 'fdi'): 1,
#  ('violenza', 'cittadino'): 12,
#  ('violenza', 'innocente'): 2,
#  ('violenza', 'imperativo'): 1,
#  ('violenza', 'corrado'): 1,
#  ('violenza', 'armeri'): 1,
#  ('violenza', 'fdi'): 1,
#  ('cittadino', 'innocente'): 6,
#  ('cittadino', 'imperativo'): 1,
#  ('cittadino', 'corrado'): 1,
#  ('cittadino', 'armeri'): 1,
#  ('cittadino', 'fdi'): 3,
#  ('innocente', 'imperativo'): 1,
#  ('innocente', 'corrado'): 1,
#  ('innocente', 'armeri'): 1,
#  ('innocente', 'fdi'): 1,
#  ('imperativo', 'corrado'): 1,
#  ('imperativo', 'armeri'): 1,
#  ('imperativo', 'fdi'): 1,
#  ('corrado', 'armeri'): 2,
#  ('corrado', 'fdi'): 1,
#  ('armeri', 'fdi'): 1,
#  ('musulmano', 'comandare'): 1,
#  ('musulmano', 'casa'): 9,
#  ('comandare', 'casa'): 23,
#  ('odio', 'dipendere'): 2,
#  ('odio', 'comandare'): 2,
#  ('odio', 'libro'): 4,
#  ('dipendere', 'comandare'): 2,
#  ('dipendere', 'libro'): 4,
#  ('comandare', 'libro'): 2,
#  ('meditato', 'sinistronzi'): 2,
#  ('tolleranza', 'rispettare'): 5,
#  ('tolleranza', 'cultura'): 1,
#  ('tolleranza', 'legge'): 6,
#  ('tolleranza', 'barcone'): 1,
#  ('rispettare', 'cultura'): 29,
#  ('rispettare', 'legge'): 129,
#  ('rispettare', 'barcone'): 2,
#  ('cultura', 'legge'): 13,
#  ('cultura', 'barcone'): 1,
#  ('legge', 'barcone'): 4,
#  ('papa', 'francesco'): 60,
#  ('papa', 'giudicare'): 3,
#  ('papa', 'sicuro'): 3,
#  ('papa', 'baciare'): 9,
#  ('papa', 'piede'): 11,
#  ('papa', 'aguzzino'): 1,
#  ('francesco', 'giudicare'): 3,
#  ('francesco', 'sicuro'): 3,
#  ('francesco', 'baciare'): 4,
#  ('francesco', 'piede'): 4,
#  ('francesco', 'aguzzino'): 1,
#  ('giudicare', 'sicuro'): 3,
#  ('giudicare', 'baciare'): 1,
#  ('giudicare', 'piede'): 2,
#  ('giudicare', 'aguzzino'): 1,
#  ('sicuro', 'baciare'): 2,
#  ('sicuro', 'piede'): 3,
#  ('sicuro', 'aguzzino'): 2,
#  ('baciare', 'piede'): 15,
#  ('baciare', 'aguzzino'): 1,
#  ('piede', 'aguzzino'): 1,
#  ('occhio', 'inghilterra'): 1,
#  ('occhio', 'governare'): 6,
#  ('occhio', 'lorsignori'): 1,
#  ('occhio', 'lotta'): 2,
#  ('occhio', 'conquistare'): 3,
#  ('occhio', 'sfogliare'): 1,
#  ('occhio', 'corano'): 4,
#  ('occhio', 'silenzioso'): 1,
#  ('occhio', 'diventera'): 1,
#  ('occhio', 'rumoroso'): 1,
#  ('occhio', 'cominciare'): 2,
#  ('occhio', 'numero'): 2,
#  ('occhio', 'politico'): 22,
#  ('occhio', 'stolto'): 3,
#  ('occhio', 'miope'): 2,
#  ('inghilterra', 'governare'): 1,
#  ('inghilterra', 'lorsignori'): 1,
#  ('inghilterra', 'lotta'): 1,
#  ('inghilterra', 'conquistare'): 1,
#  ('inghilterra', 'sfogliare'): 1,
#  ('inghilterra', 'corano'): 1,
#  ('inghilterra', 'silenzioso'): 1,
#  ('inghilterra', 'diventera'): 1,
#  ('inghilterra', 'rumoroso'): 1,
#  ('inghilterra', 'cominciare'): 1,
#  ('inghilterra', 'numero'): 1,
#  ('inghilterra', 'politico'): 2,
#  ('inghilterra', 'stolto'): 1,
#  ('inghilterra', 'miope'): 1,
#  ('governare', 'lorsignori'): 1,
#  ('governare', 'lotta'): 2,
#  ('governare', 'conquistare'): 4,
#  ('governare', 'sfogliare'): 1,
#  ('governare', 'corano'): 1,
#  ('governare', 'silenzioso'): 3,
#  ('governare', 'diventera'): 1,
#  ('governare', 'rumoroso'): 1,
#  ('governare', 'cominciare'): 7,
#  ('governare', 'numero'): 6,
#  ('governare', 'politico'): 169,
#  ('governare', 'stolto'): 1,
#  ('governare', 'miope'): 3,
#  ('lorsignori', 'lotta'): 1,
#  ('lorsignori', 'conquistare'): 1,
#  ('lorsignori', 'sfogliare'): 1,
#  ('lorsignori', 'corano'): 1,
#  ('lorsignori', 'silenzioso'): 1,
#  ('lorsignori', 'diventera'): 1,
#  ('lorsignori', 'rumoroso'): 1,
#  ('lorsignori', 'cominciare'): 1,
#  ('lorsignori', 'numero'): 1,
#  ('lorsignori', 'politico'): 1,
#  ('lorsignori', 'stolto'): 1,
#  ('lorsignori', 'miope'): 1,
#  ('lotta', 'conquistare'): 5,
#  ('lotta', 'sfogliare'): 1,
#  ('lotta', 'corano'): 1,
#  ('lotta', 'silenzioso'): 1,
#  ('lotta', 'diventera'): 1,
#  ('lotta', 'rumoroso'): 1,
#  ('lotta', 'cominciare'): 1,
#  ('lotta', 'numero'): 1,
#  ('lotta', 'politico'): 34,
#  ('lotta', 'stolto'): 1,
#  ('lotta', 'miope'): 1,
#  ('conquistare', 'sfogliare'): 1,
#  ('conquistare', 'corano'): 2,
#  ('conquistare', 'silenzioso'): 1,
#  ('conquistare', 'diventera'): 1,
#  ('conquistare', 'rumoroso'): 1,
#  ('conquistare', 'cominciare'): 2,
#  ('conquistare', 'numero'): 1,
#  ('conquistare', 'politico'): 7,
#  ('conquistare', 'stolto'): 1,
#  ('conquistare', 'miope'): 1,
#  ('sfogliare', 'corano'): 1,
#  ('sfogliare', 'silenzioso'): 1,
#  ('sfogliare', 'diventera'): 1,
#  ('sfogliare', 'rumoroso'): 1,
#  ('sfogliare', 'cominciare'): 1,
#  ('sfogliare', 'numero'): 1,
#  ('sfogliare', 'politico'): 1,
#  ('sfogliare', 'stolto'): 1,
#  ('sfogliare', 'miope'): 1,
#  ('corano', 'silenzioso'): 1,
#  ('corano', 'diventera'): 1,
#  ('corano', 'rumoroso'): 1,
#  ('corano', 'cominciare'): 1,
#  ('corano', 'numero'): 1,
#  ('corano', 'politico'): 1,
#  ('corano', 'stolto'): 1,
#  ('corano', 'miope'): 1,
#  ('silenzioso', 'diventera'): 2,
#  ('silenzioso', 'rumoroso'): 2,
#  ('silenzioso', 'cominciare'): 1,
#  ('silenzioso', 'numero'): 1,
#  ('silenzioso', 'politico'): 3,
#  ('silenzioso', 'stolto'): 1,
#  ('silenzioso', 'miope'): 1,
#  ('diventera', 'rumoroso'): 2,
#  ('diventera', 'cominciare'): 1,
#  ('diventera', 'numero'): 1,
#  ('diventera', 'politico'): 3,
#  ('diventera', 'stolto'): 1,
#  ('diventera', 'miope'): 1,
#  ('rumoroso', 'cominciare'): 1,
#  ('rumoroso', 'numero'): 1,
#  ('rumoroso', 'politico'): 1,
#  ('rumoroso', 'stolto'): 1,
#  ('rumoroso', 'miope'): 1,
#  ('cominciare', 'numero'): 1,
#  ('cominciare', 'politico'): 23,
#  ('cominciare', 'stolto'): 2,
#  ('cominciare', 'miope'): 1,
#  ('numero', 'politico'): 12,
#  ('numero', 'stolto'): 1,
#  ('numero', 'miope'): 2,
#  ('politico', 'stolto'): 3,
#  ('politico', 'miope'): 1,
#  ('stolto', 'miope'): 1,
#  ('corrado', 'creare'): 1,
#  ('corrado', 'centro'): 1,
#  ('corrado', 'raccolto'): 1,
#  ('corrado', 'rispedirli'): 1,
#  ('corrado', 'indietro'): 1,
#  ('armeri', 'creare'): 1,
#  ('armeri', 'centro'): 1,
#  ('armeri', 'raccolto'): 1,
#  ('armeri', 'rispedirli'): 1,
#  ('armeri', 'indietro'): 1,
#  ('creare', 'centro'): 12,
#  ('creare', 'raccolto'): 1,
#  ('creare', 'rispedirli'): 1,
#  ('creare', 'indietro'): 3,
#  ('centro', 'raccolto'): 4,
#  ('centro', 'rispedirli'): 1,
#  ('centro', 'indietro'): 4,
#  ('raccolto', 'rispedirli'): 1,
#  ('raccolto', 'indietro'): 3,
#  ('rispedirli', 'indietro'): 1,
#  ('senatore', 'iniziare'): 2,
#  ('senatore', 'verita'): 1,
#  ('senatore', 'islam'): 1,
#  ('senatore', 'pacifico'): 1,
#  ('senatore', 'vertice'): 1,
#  ('senatore', 'chiesa'): 1,
#  ('senatore', 'cattolico'): 1,
#  ('senatore', 'pensare'): 2,
#  ('senatore', 'diversamente'): 1,
#  ('senatore', 'paura'): 2,
#  ('senatore', 'parlare'): 12,
#  ('senatore', 'terrorismo'): 1,
#  ('senatore', 'matrice'): 1,
#  ('senatore', 'islamico'): 1,
#  ('iniziare', 'verita'): 8,
#  ('iniziare', 'islam'): 2,
#  ('iniziare', 'pacifico'): 1,
#  ('iniziare', 'vertice'): 2,
#  ('iniziare', 'chiesa'): 2,
#  ('iniziare', 'cattolico'): 2,
#  ('iniziare', 'pensare'): 11,
#  ('iniziare', 'diversamente'): 1,
#  ('iniziare', 'paura'): 2,
#  ('iniziare', 'parlare'): 38,
#  ('iniziare', 'terrorismo'): 1,
#  ('iniziare', 'matrice'): 1,
#  ('iniziare', 'islamico'): 1,
#  ('verita', 'islam'): 2,
#  ('verita', 'pacifico'): 1,
#  ('verita', 'vertice'): 1,
#  ('verita', 'chiesa'): 2,
#  ('verita', 'cattolico'): 2,
#  ('verita', 'pensare'): 9,
#  ('verita', 'diversamente'): 2,
#  ('verita', 'paura'): 6,
#  ('verita', 'parlare'): 32,
#  ('verita', 'terrorismo'): 1,
#  ('verita', 'matrice'): 1,
#  ('verita', 'islamico'): 1,
#  ('islam', 'pacifico'): 5,
#  ('islam', 'vertice'): 1,
#  ('islam', 'chiesa'): 6,
#  ('islam', 'cattolico'): 3,
#  ('islam', 'pensare'): 1,
#  ('islam', 'diversamente'): 1,
#  ('islam', 'paura'): 1,
#  ('islam', 'parlare'): 8,
#  ('islam', 'terrorismo'): 3,
#  ('islam', 'matrice'): 1,
#  ('islam', 'islamico'): 14,
#  ('pacifico', 'vertice'): 1,
#  ('pacifico', 'chiesa'): 2,
#  ('pacifico', 'cattolico'): 1,
#  ('pacifico', 'pensare'): 7,
#  ('pacifico', 'diversamente'): 1,
#  ('pacifico', 'paura'): 1,
#  ('pacifico', 'parlare'): 5,
#  ('pacifico', 'terrorismo'): 1,
#  ('pacifico', 'matrice'): 3,
#  ('pacifico', 'islamico'): 2,
#  ('vertice', 'chiesa'): 1,
#  ('vertice', 'cattolico'): 1,
#  ('vertice', 'pensare'): 2,
#  ('vertice', 'diversamente'): 1,
#  ('vertice', 'paura'): 1,
#  ('vertice', 'parlare'): 7,
#  ('vertice', 'terrorismo'): 1,
#  ('vertice', 'matrice'): 2,
#  ('vertice', 'islamico'): 1,
#  ('chiesa', 'cattolico'): 42,
#  ('chiesa', 'pensare'): 13,
#  ('chiesa', 'diversamente'): 1,
#  ('chiesa', 'paura'): 4,
#  ('chiesa', 'parlare'): 11,
#  ('chiesa', 'terrorismo'): 2,
#  ('chiesa', 'matrice'): 1,
#  ('chiesa', 'islamico'): 24,
#  ('cattolico', 'pensare'): 8,
#  ('cattolico', 'diversamente'): 1,
#  ('cattolico', 'paura'): 2,
#  ('cattolico', 'parlare'): 6,
#  ('cattolico', 'terrorismo'): 1,
#  ('cattolico', 'matrice'): 1,
#  ('cattolico', 'islamico'): 13,
#  ('pensare', 'diversamente'): 12,
#  ('pensare', 'paura'): 12,
#  ('pensare', 'parlare'): 88,
#  ('pensare', 'terrorismo'): 2,
#  ('pensare', 'matrice'): 1,
#  ('pensare', 'islamico'): 9,
#  ('diversamente', 'paura'): 2,
#  ('diversamente', 'parlare'): 4,
#  ('diversamente', 'terrorismo'): 1,
#  ('diversamente', 'matrice'): 1,
#  ('diversamente', 'islamico'): 1,
#  ('paura', 'parlare'): 31,
#  ('paura', 'terrorismo'): 1,
#  ('paura', 'matrice'): 2,
#  ('paura', 'islamico'): 3,
#  ('parlare', 'terrorismo'): 4,
#  ('parlare', 'matrice'): 3,
#  ('parlare', 'islamico'): 12,
#  ('terrorismo', 'matrice'): 1,
#  ('terrorismo', 'islamico'): 8,
#  ('matrice', 'islamico'): 2,
#  ('buonista', 'comunista'): 2,
#  ('buonista', 'trasferta'): 1,
#  ('buonista', 'trovarli'): 1,
#  ('buonista', 'possibilmente'): 1,
#  ('buonista', 'rimanerci'): 1,
#  ('comunista', 'trasferta'): 1,
#  ('comunista', 'trovarli'): 1,
#  ('comunista', 'possibilmente'): 2,
#  ('comunista', 'rimanerci'): 1,
#  ('trasferta', 'trovarli'): 1,
#  ('trasferta', 'possibilmente'): 1,
#  ('trasferta', 'rimanerci'): 1,
#  ('trovarli', 'possibilmente'): 1,
#  ('trovarli', 'rimanerci'): 1,
#  ('possibilmente', 'rimanerci'): 1,
#  ('on', 'gemmare'): 3,
#  ('on', 'cogliere'): 2,
#  ('on', 'occasione'): 2,
#  ('on', 'rammentare'): 2,
#  ('on', 'proposta'): 2,
#  ('on', 'attuale'): 2,
#  ('on', 'pertinente'): 1,
#  ('on', 'compreso'): 1,
#  ('on', 'situazione'): 1,
#  ('on', 'italia'): 6,
#  ('on', 'migliorare'): 1,
#  ('on', 'fronte'): 2,
#  ('on', 'cordiale'): 3,
#  ('on', 'saluto'): 4,
#  ('gemmare', 'cogliere'): 1,
#  ('gemmare', 'occasione'): 1,
#  ('gemmare', 'rammentare'): 1,
#  ('gemmare', 'proposta'): 1,
#  ('gemmare', 'attuale'): 1,
#  ('gemmare', 'pertinente'): 1,
#  ('gemmare', 'compreso'): 1,
#  ('gemmare', 'situazione'): 1,
#  ('gemmare', 'italia'): 2,
#  ('gemmare', 'migliorare'): 1,
#  ('gemmare', 'fronte'): 1,
#  ('gemmare', 'cordiale'): 1,
#  ('gemmare', 'saluto'): 1,
#  ('cogliere', 'occasione'): 9,
#  ('cogliere', 'rammentare'): 1,
#  ('cogliere', 'proposta'): 2,
#  ('cogliere', 'attuale'): 1,
#  ('cogliere', 'pertinente'): 1,
#  ('cogliere', 'compreso'): 1,
#  ('cogliere', 'situazione'): 2,
#  ('cogliere', 'italia'): 4,
#  ('cogliere', 'migliorare'): 1,
#  ('cogliere', 'fronte'): 1,
#  ('cogliere', 'cordiale'): 1,
#  ('cogliere', 'saluto'): 2,
#  ('occasione', 'rammentare'): 2,
#  ('occasione', 'proposta'): 4,
#  ('occasione', 'attuale'): 2,
#  ('occasione', 'pertinente'): 1,
#  ('occasione', 'compreso'): 1,
#  ('occasione', 'situazione'): 3,
#  ('occasione', 'italia'): 17,
#  ('occasione', 'migliorare'): 2,
#  ('occasione', 'fronte'): 6,
#  ('occasione', 'cordiale'): 1,
#  ('occasione', 'saluto'): 3,
#  ('rammentare', 'proposta'): 1,
#  ('rammentare', 'attuale'): 2,
#  ('rammentare', 'pertinente'): 1,
#  ('rammentare', 'compreso'): 1,
#  ('rammentare', 'situazione'): 1,
#  ('rammentare', 'italia'): 2,
#  ('rammentare', 'migliorare'): 1,
#  ('rammentare', 'fronte'): 1,
#  ('rammentare', 'cordiale'): 1,
#  ('rammentare', 'saluto'): 1,
#  ('proposta', 'attuale'): 6,
#  ('proposta', 'pertinente'): 1,
#  ('proposta', 'compreso'): 1,
#  ('proposta', 'situazione'): 3,
#  ('proposta', 'italia'): 22,
#  ('proposta', 'migliorare'): 6,
#  ('proposta', 'fronte'): 5,
#  ('proposta', 'cordiale'): 1,
#  ('proposta', 'saluto'): 2,
#  ('attuale', 'pertinente'): 1,
#  ('attuale', 'compreso'): 2,
#  ('attuale', 'situazione'): 7,
#  ('attuale', 'italia'): 30,
#  ('attuale', 'migliorare'): 7,
#  ('attuale', 'fronte'): 1,
#  ('attuale', 'cordiale'): 1,
#  ('attuale', 'saluto'): 4,
#  ('pertinente', 'compreso'): 1,
#  ('pertinente', 'situazione'): 1,
#  ('pertinente', 'italia'): 1,
#  ('pertinente', 'migliorare'): 1,
#  ('pertinente', 'fronte'): 1,
#  ('pertinente', 'cordiale'): 1,
#  ('pertinente', 'saluto'): 1,
#  ('compreso', 'situazione'): 3,
#  ('compreso', 'italia'): 19,
#  ('compreso', 'migliorare'): 1,
#  ('compreso', 'fronte'): 2,
#  ('compreso', 'cordiale'): 1,
#  ('compreso', 'saluto'): 2,
#  ('situazione', 'italia'): 42,
#  ('situazione', 'migliorare'): 14,
#  ('situazione', 'fronte'): 8,
#  ('situazione', 'cordiale'): 1,
#  ('situazione', 'saluto'): 4,
#  ('italia', 'migliorare'): 34,
#  ('italia', 'fronte'): 34,
#  ('italia', 'cordiale'): 4,
#  ('italia', 'saluto'): 35,
#  ('migliorare', 'fronte'): 2,
#  ('migliorare', 'cordiale'): 1,
#  ('migliorare', 'saluto'): 1,
#  ('fronte', 'cordiale'): 1,
#  ('fronte', 'saluto'): 6,
#  ('cordiale', 'saluto'): 21,
#  ('escremento', 'umano'): 1,
#  ('infilare', 'culetto'): 1,
#  ('infilare', 'antifa'): 1,
#  ('infilare', 'suppostina'): 1,
#  ('infilare', 'figlio'): 2,
#  ('infilare', 'brigatista'): 1,
#  ('infilare', 'assassino'): 1,
#  ('culetto', 'antifa'): 1,
#  ('culetto', 'suppostina'): 1,
#  ('culetto', 'figlio'): 1,
#  ('culetto', 'brigatista'): 1,
#  ('culetto', 'assassino'): 1,
#  ('antifa', 'suppostina'): 1,
#  ('antifa', 'figlio'): 1,
#  ('antifa', 'brigatista'): 1,
#  ('antifa', 'assassino'): 1,
#  ('suppostina', 'figlio'): 1,
#  ('suppostina', 'brigatista'): 1,
#  ('suppostina', 'assassino'): 1,
#  ('figlio', 'brigatista'): 2,
#  ('figlio', 'assassino'): 4,
#  ('brigatista', 'assassino'): 1,
#  ('pezzo', 'merda'): 39,
#  ('pezzo', 'italia'): 9,
#  ('pezzo', 'schifare'): 3,
#  ('pezzo', 'italiano'): 18,
#  ('merda', 'italia'): 50,
#  ('merda', 'schifare'): 12,
#  ('merda', 'italiano'): 56,
#  ('italia', 'schifare'): 31,
#  ('italia', 'italiano'): 1074,
#  ('schifare', 'italiano'): 52,
#  ('lurido', 'escremento'): 1,
#  ('lurido', 'putrefare'): 1,
#  ('lurido', 'anti'): 1,
#  ('lurido', 'italiano'): 1,
#  ('lurido', 'servo'): 1,
#  ('lurido', 'pd'): 2,
#  ('lurido', 'sinistroidi'): 1,
#  ('lurido', 'feccia'): 1,
#  ('lurido', 'umanita'): 1,
#  ('lurido', 'vergognatevi'): 2,
#  ('escremento', 'putrefare'): 1,
#  ('escremento', 'anti'): 1,
#  ('escremento', 'italiano'): 1,
#  ('escremento', 'servo'): 1,
#  ('escremento', 'pd'): 1,
#  ('escremento', 'sinistroidi'): 1,
#  ('escremento', 'feccia'): 1,
#  ('escremento', 'umanita'): 1,
#  ('escremento', 'vergognatevi'): 1,
#  ('putrefare', 'anti'): 1,
#  ('putrefare', 'italiano'): 1,
#  ('putrefare', 'servo'): 1,
#  ('putrefare', 'pd'): 1,
#  ('putrefare', 'sinistroidi'): 1,
#  ('putrefare', 'feccia'): 1,
#  ('putrefare', 'umanita'): 1,
#  ('putrefare', 'vergognatevi'): 1,
#  ('anti', 'italiano'): 34,
#  ('anti', 'servo'): 2,
#  ('anti', 'pd'): 16,
#  ('anti', 'sinistroidi'): 2,
#  ('anti', 'feccia'): 1,
#  ('anti', 'umanita'): 1,
#  ('anti', 'vergognatevi'): 2,
#  ('italiano', 'servo'): 5,
#  ('italiano', 'pd'): 432,
#  ('italiano', 'sinistroidi'): 8,
#  ('italiano', 'feccia'): 7,
#  ('italiano', 'umanita'): 31,
#  ('italiano', 'vergognatevi'): 23,
#  ('servo', 'pd'): 10,
#  ('servo', 'sinistroidi'): 1,
#  ('servo', 'feccia'): 1,
#  ('servo', 'umanita'): 1,
#  ('servo', 'vergognatevi'): 1,
#  ('pd', 'sinistroidi'): 3,
#  ('pd', 'feccia'): 8,
#  ('pd', 'umanita'): 6,
#  ('pd', 'vergognatevi'): 12,
#  ('sinistroidi', 'feccia'): 1,
#  ('sinistroidi', 'umanita'): 1,
#  ('sinistroidi', 'vergognatevi'): 1,
#  ('feccia', 'umanita'): 5,
#  ('feccia', 'vergognatevi'): 1,
#  ('umanita', 'vergognatevi'): 1,
#  ...}

# %%
##lets obtain the nodes list and edge lists
#UNWEIGHTED
G = nx.Graph()
G.add_edges_from(words_projection)
print(G.edges)
print(G.nodes)

nx.write_edgelist(G,"commentsunweighted_edgelist.csv",delimiter=",")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# !sed -i.bak 1i"Source,Target,Weight" commentsunweighted_edgelist.csv
# Out:
# sed: 1: "1iSource,Target,Weight": command i expects \ followed by text

# %% [markdown]
# **Create an Edges List**

# %%
##edge lists
#WEIGHTED
#to get weighted graph we need a list of 3-element tuplels (u,v,w) where u and v are nodes 
## and w is a number representing weight

words_weighted = []
for edge in words_projection:
    words_weighted.append((edge[0],edge[1],words_projection[edge]))

G = nx.Graph()
G.add_weighted_edges_from(words_weighted)

print(G.edges)
print(G.nodes)

nx.write_weighted_edgelist(G, "words_edgelist_weighted.csv",delimiter=",") ##save the edges list as csv
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# !sed -i.bak 1i"Source,Target,Weight" words_edgelist_weighted.csv ##insert columns source, target, weight to the node list
# Out:
# sed: 1: "1iSource,Target,Weight": command i expects \ followed by text

# %%
##Create edges from Pandas data frame

G_df = nx.from_pandas_adjacency(clean_df)

print(G_df.edges)
print(G_df.nodes)
nx.write_weighted_edgelist(G, "words_edgelist_2.csv",delimiter=",")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# !sed -i.bak 1i"Source,Target,Weight" words_edgelist_2.csv
# Out:
# sed: 1: "1iSource,Target,Weight": command i expects \ followed by text

# %%
##lets create a node list
nl_df = pd.DataFrame.from_dict(unique_words,orient="index")
nl_df.reset_index(inplace=True)
nl_df[0] = nl_df['index']
nl_df.rename(columns={"index":"Id", 0:"Label"},inplace=True)


nl_df.to_csv("words_nodelist.csv",index=False)

# %%
###We now have nodes list and edges list
##We can now use the weighted edge list and node list to create graphs in Gephi
